# %%
# !pip install --upgrade pycaret
# !pip install cuml
# !pip install pycaret --upgrade

# %%
import pandas as pd
import numpy as np
from pycaret.regression import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = pd.ExcelFile(".\data\\food-twentieth-century-crop-statistics-1900-2017-xlsx.xlsx")
df = file.parse('CropStats')
df = df.set_index(df.columns[0])
df.index.name = None

# %% [markdown]
# ## Clean Data
# Columns with too many null values or meaningless information are dropped.
# Columns with unclear names are renamed.
# For the subnational column null values are filled up with corresponding values from the national column.
# For yield, production, and hectares, if one of them is null but the others in the same row are not, the null one can be calculated. Here we need to pay attention to not divide by 0.
# We chose to focus on wheat, so we will be filtering the df accordingly.
# We also added columns with logarithmic transformations for yield, production, and hectares.

# %%
df.drop(['admin2', 'notes', 'Harvest_year'], axis=1, inplace=True)
df.rename(columns = {'admin0': 'national', 'admin1': 'subnational', 'hectares (ha)': 'hectares_ha', 'production (tonnes)': 'production_tonnes', 'yield(tonnes/ha)': 'yield_tonnes_ha'}, inplace=True)
df.loc[df['subnational'].isna(), 'subnational'] = df['national']
# Calculate yield
mask = df['yield_tonnes_ha'].isna() & ~df['production_tonnes'].isna() & ~df['hectares_ha'].isna() & df['hectares_ha'] != 0
df.loc[mask, 'yield_tonnes_ha'] = df['production_tonnes'] / df['hectares_ha']
df.dropna(subset=['yield_tonnes_ha'], inplace=True)
# Calculate production
mask = df['production_tonnes'].isna() & ~df['yield_tonnes_ha'].isna() & ~df['hectares_ha'].isna()
df.loc[mask, 'production_tonnes'] = df['yield_tonnes_ha'] * df['hectares_ha']
df.dropna(subset=['production_tonnes'], inplace=True)
# Calculate hectares
mask = df['hectares_ha'].isna() & ~df['yield_tonnes_ha'].isna() & ~df['production_tonnes'].isna()
df.loc[mask, 'hectares_ha'] = df['yield_tonnes_ha'] * df['production_tonnes']
df.dropna(subset=['hectares_ha'], inplace=True)
# The columns we just adapted just changed into objects, let's make them floats again
df['hectares_ha'] = df['hectares_ha'].astype(float)
df['production_tonnes'] = df['production_tonnes'].astype(float)
df['yield_tonnes_ha'] = df['yield_tonnes_ha'].astype(float)
# Filter for wheat
df = df[df['crop'] == 'wheat']
# Remove the crop column
df.drop('crop', axis=1, inplace =True)
# Logarithmic transformations
df['log_yield'] = np.log1p(df['yield_tonnes_ha'])
df['log_hectares'] = np.log1p(df['production_tonnes'])
df['log_production'] = np.log1p(df['hectares_ha'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15479 entries, 59 to 36706
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   national           15479 non-null  object
#  1   subnational        15479 non-null  object
#  2   hectares_ha        15479 non-null  float64
#  3   production_tonnes  15479 non-null  float64
#  4   year               15479 non-null  int64
#  5   yield_tonnes_ha    15479 non-null  float64
#  6   log_yield          15479 non-null  float64
#  7   log_hectares       15479 non-null  float64
#  8   log_production     15479 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Training the Model
# After some testing it has been determined that using the log values gives better results.
# Excluding the subnational column also gave slightly better results (I also tried omitting hectares and production as they seemed to have low importance in the feature importance tab, but that made the model less accurate).
# The df is prepped accordingly.

# %%
cat_features = ['national']
df.drop(['yield_tonnes_ha', 'hectares_ha', 'production_tonnes', 'subnational'], axis=1, inplace=True)

# %% [markdown]
# Eventually, we will want to do some predictions, so here we split the df. The bottom 20% we will set aside to make predictions and test the model.

# %%
split_index = int(len(df) * 0.2)
train_data = df.iloc[split_index:]
prediction_data_raw = df.iloc[:split_index]
prediction_data = prediction_data_raw.drop('log_yield', axis=1)

# %%
experiment = setup(train_data, target='log_yield', session_id=123)
# Out:
# <style type="text/css">
# #T_83082_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83082">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83082_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_83082_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83082_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83082_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_83082_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83082_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83082_row1_col1" class="data row1 col1" >log_yield</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83082_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_83082_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83082_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_83082_row3_col1" class="data row3 col1" >(12384, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83082_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_83082_row4_col1" class="data row4 col1" >(12384, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83082_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_83082_row5_col1" class="data row5 col1" >(8668, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83082_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_83082_row6_col1" class="data row6 col1" >(3716, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83082_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_83082_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83082_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_83082_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83082_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_83082_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_83082_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_83082_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_83082_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_83082_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_83082_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_83082_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_83082_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_83082_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_83082_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_83082_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_83082_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_83082_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_83082_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_83082_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_83082_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_83082_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_83082_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_83082_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_83082_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_83082_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_83082_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_83082_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_83082_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_83082_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_83082_row21_col1" class="data row21 col1" >9974</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_models = compare_models(n_select=5)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           12:35:26
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_c635b th {
#   text-align: left;
# }
# #T_c635b_row0_col0, #T_c635b_row1_col0, #T_c635b_row1_col1, #T_c635b_row1_col2, #T_c635b_row1_col3, #T_c635b_row1_col4, #T_c635b_row1_col5, #T_c635b_row1_col6, #T_c635b_row2_col0, #T_c635b_row2_col1, #T_c635b_row2_col2, #T_c635b_row2_col3, #T_c635b_row2_col4, #T_c635b_row2_col5, #T_c635b_row2_col6, #T_c635b_row3_col0, #T_c635b_row3_col1, #T_c635b_row3_col2, #T_c635b_row3_col3, #T_c635b_row3_col4, #T_c635b_row3_col5, #T_c635b_row3_col6, #T_c635b_row4_col0, #T_c635b_row4_col1, #T_c635b_row4_col2, #T_c635b_row4_col3, #T_c635b_row4_col4, #T_c635b_row4_col5, #T_c635b_row4_col6, #T_c635b_row5_col0, #T_c635b_row5_col1, #T_c635b_row5_col2, #T_c635b_row5_col3, #T_c635b_row5_col4, #T_c635b_row5_col5, #T_c635b_row5_col6, #T_c635b_row6_col0, #T_c635b_row6_col1, #T_c635b_row6_col2, #T_c635b_row6_col3, #T_c635b_row6_col4, #T_c635b_row6_col5, #T_c635b_row6_col6, #T_c635b_row7_col0, #T_c635b_row7_col1, #T_c635b_row7_col2, #T_c635b_row7_col3, #T_c635b_row7_col4, #T_c635b_row7_col5, #T_c635b_row7_col6, #T_c635b_row8_col0, #T_c635b_row8_col1, #T_c635b_row8_col2, #T_c635b_row8_col3, #T_c635b_row8_col4, #T_c635b_row8_col5, #T_c635b_row8_col6, #T_c635b_row9_col0, #T_c635b_row9_col1, #T_c635b_row9_col2, #T_c635b_row9_col3, #T_c635b_row9_col4, #T_c635b_row9_col5, #T_c635b_row9_col6, #T_c635b_row10_col0, #T_c635b_row10_col1, #T_c635b_row10_col2, #T_c635b_row10_col3, #T_c635b_row10_col4, #T_c635b_row10_col5, #T_c635b_row10_col6, #T_c635b_row11_col0, #T_c635b_row11_col1, #T_c635b_row11_col2, #T_c635b_row11_col3, #T_c635b_row11_col4, #T_c635b_row11_col5, #T_c635b_row11_col6, #T_c635b_row12_col0, #T_c635b_row12_col1, #T_c635b_row12_col2, #T_c635b_row12_col3, #T_c635b_row12_col4, #T_c635b_row12_col5, #T_c635b_row12_col6, #T_c635b_row13_col0, #T_c635b_row13_col1, #T_c635b_row13_col2, #T_c635b_row13_col3, #T_c635b_row13_col4, #T_c635b_row13_col5, #T_c635b_row13_col6, #T_c635b_row14_col0, #T_c635b_row14_col1, #T_c635b_row14_col2, #T_c635b_row14_col3, #T_c635b_row14_col4, #T_c635b_row14_col5, #T_c635b_row14_col6, #T_c635b_row15_col0, #T_c635b_row15_col1, #T_c635b_row15_col2, #T_c635b_row15_col3, #T_c635b_row15_col4, #T_c635b_row15_col5, #T_c635b_row15_col6, #T_c635b_row16_col0, #T_c635b_row16_col1, #T_c635b_row16_col2, #T_c635b_row16_col3, #T_c635b_row16_col4, #T_c635b_row16_col5, #T_c635b_row16_col6, #T_c635b_row17_col0, #T_c635b_row17_col1, #T_c635b_row17_col2, #T_c635b_row17_col3, #T_c635b_row17_col4, #T_c635b_row17_col5, #T_c635b_row17_col6, #T_c635b_row18_col0, #T_c635b_row18_col1, #T_c635b_row18_col2, #T_c635b_row18_col3, #T_c635b_row18_col4, #T_c635b_row18_col5, #T_c635b_row18_col6 {
#   text-align: left;
# }
# #T_c635b_row0_col1, #T_c635b_row0_col2, #T_c635b_row0_col3, #T_c635b_row0_col4, #T_c635b_row0_col5, #T_c635b_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c635b_row0_col7, #T_c635b_row1_col7, #T_c635b_row2_col7, #T_c635b_row3_col7, #T_c635b_row4_col7, #T_c635b_row5_col7, #T_c635b_row6_col7, #T_c635b_row7_col7, #T_c635b_row8_col7, #T_c635b_row9_col7, #T_c635b_row10_col7, #T_c635b_row11_col7, #T_c635b_row12_col7, #T_c635b_row13_col7, #T_c635b_row14_col7, #T_c635b_row15_col7, #T_c635b_row16_col7, #T_c635b_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c635b_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c635b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c635b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c635b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c635b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c635b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c635b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c635b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c635b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c635b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c635b_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_c635b_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c635b_row0_col1" class="data row0 col1" >0.0344</td>
#       <td id="T_c635b_row0_col2" class="data row0 col2" >0.0024</td>
#       <td id="T_c635b_row0_col3" class="data row0 col3" >0.0490</td>
#       <td id="T_c635b_row0_col4" class="data row0 col4" >0.9881</td>
#       <td id="T_c635b_row0_col5" class="data row0 col5" >0.0243</td>
#       <td id="T_c635b_row0_col6" class="data row0 col6" >0.0375</td>
#       <td id="T_c635b_row0_col7" class="data row0 col7" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_c635b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_c635b_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_c635b_row1_col1" class="data row1 col1" >0.0382</td>
#       <td id="T_c635b_row1_col2" class="data row1 col2" >0.0037</td>
#       <td id="T_c635b_row1_col3" class="data row1 col3" >0.0611</td>
#       <td id="T_c635b_row1_col4" class="data row1 col4" >0.9815</td>
#       <td id="T_c635b_row1_col5" class="data row1 col5" >0.0301</td>
#       <td id="T_c635b_row1_col6" class="data row1 col6" >0.0421</td>
#       <td id="T_c635b_row1_col7" class="data row1 col7" >0.5900</td>
#     </tr>
#     <tr>
#       <th id="T_c635b_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_c635b_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c635b_row2_col1" class="data row2 col1" >0.0467</td>
#       <td id="T_c635b_row2_col2" class="data row2 col2" >0.0043</td>
#       <td id="T_c635b_row2_col3" class="data row2 col3" >0.0654</td>
#       <td id="T_c635b_row2_col4" class="data row2 col4" >0.9789</td>
#       <td id="T_c635b_row2_col5" class="data row2 col5" >0.0319</td>
#       <td id="T_c635b_row2_col6" class="data row2 col6" >0.0514</td>
#       <td id="T_c635b_row2_col7" class="data row2 col7" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_c635b_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_c635b_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_c635b_row3_col1" class="data row3 col1" >0.0416</td>
#       <td id="T_c635b_row3_col2" class="data row3 col2" >0.0043</td>
#       <td id="T_c635b_row3_col3" class="data row3 col3" >0.0656</td>
#       <td id="T_c635b_row3_col4" class="data row3 col4" >0.9786</td>
#       <td id="T_c635b_row3_col5" class="data row3 col5" >0.0326</td>
#       <td id="T_c635b_row3_col6" class="data row3 col6" >0.0469</td>
#       <td id="T_c635b_row3_col7" class="data row3 col7" >0.2900</td>
#     </tr>
#     <tr>
#       <th id="T_c635b_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_c635b_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_c635b_row4_col1" class="data row4 col1" >0.0555</td>
#       <td id="T_c635b_row4_col2" class="data row4 col2" >0.0077</td>
#       <td id="T_c635b_row4_col3" class="data row4 col3" >0.0875</td>
#       <td id="T_c635b_row4_col4" class="data row4 col4" >0.9621</td>
#       <td id="T_c635b_row4_col5" class="data row4 col5" >0.0427</td>
#       <td id="T_c635b_row4_col6" class="data row4 col6" >0.0603</td>
#       <td id="T_c635b_row4_col7" class="data row4 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_c635b_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_c635b_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_c635b_row5_col1" class="data row5 col1" >0.0636</td>
#       <td id="T_c635b_row5_col2" class="data row5 col2" >0.0159</td>
#       <td id="T_c635b_row5_col3" class="data row5 col3" >0.1113</td>
#       <td id="T_c635b_row5_col4" class="data row5 col4" >0.9224</td>
#       <td id="T_c635b_row5_col5" class="data row5 col5" >0.0477</td>
#       <td id="T_c63

# %%
best_model = best_models[0]

# %%
best_model = tune_model(best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   12:35:48
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# <style type="text/css">
# #T_be762_row10_col0, #T_be762_row10_col1, #T_be762_row10_col2, #T_be762_row10_col3, #T_be762_row10_col4, #T_be762_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_be762">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be762_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_be762_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_be762_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_be762_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_be762_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_be762_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be762_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be762_row0_col0" class="data row0 col0" >0.0305</td>
#       <td id="T_be762_row0_col1" class="data row0 col1" >0.0018</td>
#       <td id="T_be762_row0_col2" class="data row0 col2" >0.0428</td>
#       <td id="T_be762_row0_col3" class="data row0 col3" >0.9916</td>
#       <td id="T_be762_row0_col4" class="data row0 col4" >0.0211</td>
#       <td id="T_be762_row0_col5" class="data row0 col5" >0.0342</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be762_row1_col0" class="data row1 col0" >0.0319</td>
#       <td id="T_be762_row1_col1" class="data row1 col1" >0.0021</td>
#       <td id="T_be762_row1_col2" class="data row1 col2" >0.0453</td>
#       <td id="T_be762_row1_col3" class="data row1 col3" >0.9900</td>
#       <td id="T_be762_row1_col4" class="data row1 col4" >0.0211</td>
#       <td id="T_be762_row1_col5" class="data row1 col5" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be762_row2_col0" class="data row2 col0" >0.0314</td>
#       <td id="T_be762_row2_col1" class="data row2 col1" >0.0026</td>
#       <td id="T_be762_row2_col2" class="data row2 col2" >0.0509</td>
#       <td id="T_be762_row2_col3" class="data row2 col3" >0.9875</td>
#       <td id="T_be762_row2_col4" class="data row2 col4" >0.0271</td>
#       <td id="T_be762_row2_col5" class="data row2 col5" >0.0405</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be762_row3_col0" class="data row3 col0" >0.0330</td>
#       <td id="T_be762_row3_col1" class="data row3 col1" >0.0022</td>
#       <td id="T_be762_row3_col2" class="data row3 col2" >0.0464</td>
#       <td id="T_be762_row3_col3" class="data row3 col3" >0.9891</td>
#       <td id="T_be762_row3_col4" class="data row3 col4" >0.0225</td>
#       <td id="T_be762_row3_col5" class="data row3 col5" >0.0353</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be762_row4_col0" class="data row4 col0" >0.0306</td>
#       <td id="T_be762_row4_col1" class="data row4 col1" >0.0019</td>
#       <td id="T_be762_row4_col2" class="data row4 col2" >0.0438</td>
#       <td id="T_be762_row4_col3" class="data row4 col3" >0.9909</td>
#       <td id="T_be762_row4_col4" class="data row4 col4" >0.0205</td>
#       <td id="T_be762_row4_col5" class="data row4 col5" >0.0313</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be762_row5_col0" class="data row5 col0" >0.0343</td>
#       <td id="T_be762_row5_col1" class="data row5 col1" >0.0025</td>
#       <td id="T_be762_row5_col2" class="data row5 col2" >0.0496</td>
#       <td id="T_be762_row5_col3" class="data row5 col3" >0.9877</td>
#       <td id="T_be762_row5_col4" class="data row5 col4" >0.0239</td>
#       <td id="T_be762_row5_col5" class="data row5 col5" >0.0366</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be762_row6_col0" class="data row6 col0" >0.0302</td>
#       <td id="T_be762_row6_col1" class="data row6 col1" >0.0018</td>
#       <td id="T_be762_row6_col2" class="data row6 col2" >0.0430</td>
#       <td id="T_be762_row6_col3" class="data row6 col3" >0.9905</td>
#       <td id="T_be762_row6_col4" class="data row6 col4" >0.0210</td>
#       <td id="T_be762_row6_col5" class="data row6 col5" >0.0328</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be762_row7_col0" class="data row7 col0" >0.0341</td>
#       <td id="T_be762_row7_col1" class="data row7 col1" >0.0024</td>
#       <td id="T_be762_row7_col2" class="data row7 col2" >0.0487</td>
#       <td id="T_be762_row7_col3" class="data row7 col3" >0.9874</td>
#       <td id="T_be762_row7_col4" class="data row7 col4" >0.0244</td>
#       <td id="T_be762_row7_col5" class="data row7 col5" >0.0373</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be762_row8_col0" class="data row8 col0" >0.0318</td>
#       <td id="T_be762_row8_col1" class="data row8 col1" >0.0020</td>
#       <td id="T_be762_row8_col2" class="data row8 col2" >0.0452</td>
#       <td id="T_be762_row8_col3" class="data row8 col3" >0.9905</td>
#       <td id="T_be762_row8_col4" class="data row8 col4" >0.0216</td>
#       <td id="T_be762_row8_col5" class="data row8 col5" >0.0357</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be762_row9_col0" class="data row9 col0" >0.0323</td>
#       <td id="T_be762_row9_col1" class="data row9 col1" >0.0022</td>
#       <td id="T_be762_row9_col2" class="data row9 col2" >0.0467</td>
#       <td id="T_be762_row9_col3" class="data row9 col3" >0.9891</td>
#       <td id="T_be762_row9_col4" class="data row9 col4" >0.0231</td>
#       <td id="T_be762_row9_col5" class="data row9 col5" >0.0348</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_be762_row10_col0" class="data row10 col0" >0.0320</td>
#       <td id="T_be762_row10_col1" class="data row10 col1" >0.0021</td>
#       <td id="T_be762_row10_col2" class="data row10 col2" >0.0462</td>
#       <td id="T_be762_row10_col3" class="data row10 col3" >0.9894</td>
#       <td id="T_be762_row10_col4" class="data row10 col4" >0.0226</td>
#       <td id="T_be762_row10_col5" class="data row10 col5" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_be762_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_be762_row11_col0" class="data row11 col0" >0.0014</td>
#       <td id="T_be762_row11_col1" class="data row11 col1" >0.0002</td>
#       <td id="T_be762_row11_col2" class="data row11 col2" >0.0026</td>
#       <td id="T_be762_row11_col3" class="data row11 col3" >0.0014</td>
#       <td id="T_be762_row11_col4" class="data row11 col4" >0.0020</td>
#       <td id="T_be762_row11_col5" class="data row11 col5" >0.0026</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best_model, data=prediction_data)
predictions.head()
# Out:
#    national  year  log_hectares  log_production  prediction_label
# 59  Austria  1961     13.475302       12.527514          1.164535
# 60  Austria  1962     13.467594       12.507480          1.172159
# 61  Austria  1963     13.443799       12.523519          1.169994
# 62  Austria  1964     13.528401       12.553089          1.224141
# 63  Austria  1965     13.401121       12.526905          1.146664

# %%
save_model(best_model, 'crops_emalisa')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['year', 'log_hectares',
#                                               'log_production'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['national'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['national'],
#                                      transforme...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=10, max_leaves=None, min_child_weight=4,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=220, n_jobs=-1,
#                                num_parallel_tree=None, random_state=123, ...))]),
#  'crops_emalisa.pkl')

# %% [markdown]
# #### Making Predictions
# PyCaret tells us about the predictive capabilities of our model, but I would like to put it to the test myself.

# %%
df_analysis = pd.DataFrame({'Actual Values': prediction_data_raw['log_yield'], 'Predicted Values': predictions['prediction_label']})
sns.scatterplot(data=df_analysis, x='Actual Values', y='Predicted Values', palette='colorblind').set(title='Predicted vs Actual Values')
# Out:
# [Text(0.5, 1.0, 'Predicted vs Actual Values')]

# %%
residuals = np.array(prediction_data_raw['log_yield']) - np.array(predictions['prediction_label'])

plt.figure(figsize=(8, 6))
sns.scatterplot(data=predictions, x='prediction_label', y=residuals, palette='colorblind')
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.grid(True)

# Show the plot
plt.show()
