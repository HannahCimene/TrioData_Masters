# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.regression import *

# %%
file = pd.ExcelFile(".\data\\food-twentieth-century-crop-statistics-1900-2017-xlsx.xlsx")
df = file.parse('CropStats')
df = df.set_index(df.columns[0])
df.index.name = None

# %% [markdown]
# ## Clean Data
# Columns with too many null values or meaningless information are dropped.
# Columns with unclear names are renamed.
# For the subnational column null values are filled up with corresponding values from the national column.
# For yield, production, and hectares, if one of them is null but the others in the same row are not, the null one can be calculated. Here we need to pay attention to not divide by 0.
# We chose to focus on wheat, so we will be filtering the df accordingly.
# We also added columns with logarithmic transformations for yield, production, and hectares.

# %%
df.drop(['admin2', 'notes', 'Harvest_year'], axis=1, inplace=True)
df.rename(columns = {'admin0': 'national', 'admin1': 'subnational', 'hectares (ha)': 'hectares_ha', 'production (tonnes)': 'production_tonnes', 'yield(tonnes/ha)': 'yield_tonnes_ha'}, inplace=True)
df.loc[df['subnational'].isna(), 'subnational'] = df['national']
# Calculate yield
mask = df['yield_tonnes_ha'].isna() & ~df['production_tonnes'].isna() & ~df['hectares_ha'].isna() & df['hectares_ha'] != 0
df.loc[mask, 'yield_tonnes_ha'] = df['production_tonnes'] / df['hectares_ha']
df.dropna(subset=['yield_tonnes_ha'], inplace=True)
# Calculate production
mask = df['production_tonnes'].isna() & ~df['yield_tonnes_ha'].isna() & ~df['hectares_ha'].isna()
df.loc[mask, 'production_tonnes'] = df['yield_tonnes_ha'] * df['hectares_ha']
df.dropna(subset=['production_tonnes'], inplace=True)
# Calculate hectares
mask = df['hectares_ha'].isna() & ~df['yield_tonnes_ha'].isna() & ~df['production_tonnes'].isna()
df.loc[mask, 'hectares_ha'] = df['yield_tonnes_ha'] * df['production_tonnes']
df.dropna(subset=['hectares_ha'], inplace=True)
# The columns we just adapted just changed into objects, let's make them floats again
df['hectares_ha'] = df['hectares_ha'].astype(float)
df['production_tonnes'] = df['production_tonnes'].astype(float)
df['yield_tonnes_ha'] = df['yield_tonnes_ha'].astype(float)
# Filter for wheat
df = df[df['crop'] == 'wheat']
# Remove the crop column
df.drop('crop', axis=1, inplace =True)
# Logarithmic transformations
# df['log_yield'] = np.log1p(df['yield_tonnes_ha'])
# df['log_hectares'] = np.log1p(df['production_tonnes'])
# df['log_production'] = np.log1p(df['hectares_ha'])

# %%
belgium = df[df['national'] == 'Belgium']
belgium.head()
# Out:
#     national subnational  hectares_ha  production_tonnes  year  \
# 175  Belgium     Belgium     212139.0          753093.45  1961
# 176  Belgium     Belgium     212221.0          876472.73  1962
# 177  Belgium     Belgium     201443.0          743324.67  1963
# 178  Belgium     Belgium     217656.0          916331.76  1964
# 179  Belgium     Belgium     229353.0          864660.81  1965
#
#      yield_tonnes_ha
# 175             3.55
# 176             4.13
# 177             3.69
# 178             4.21
# 179             3.77

# %%
train = df[df['year'] < 2007]
test = df[df['year'] >= 2007]

# %%
s = setup(data = train, test_data = test, target = 'yield_tonnes_ha', fold_strategy = 'timeseries', numeric_features = ['year', 'production_tonnes', 'hectares_ha'], fold = 3, transform_target = True, session_id = 123, data_split_shuffle = False, fold_shuffle = False)
# Out:
# <style type="text/css">
# #T_c6154_row9_col1, #T_c6154_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c6154">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6154_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c6154_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6154_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6154_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c6154_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6154_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c6154_row1_col1" class="data row1 col1" >yield_tonnes_ha</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6154_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c6154_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6154_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c6154_row3_col1" class="data row3 col1" >(15479, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c6154_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c6154_row4_col1" class="data row4 col1" >(15479, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c6154_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c6154_row5_col1" class="data row5 col1" >(14013, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c6154_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c6154_row6_col1" class="data row6 col1" >(1466, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c6154_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c6154_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c6154_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_c6154_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c6154_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c6154_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c6154_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c6154_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c6154_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c6154_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c6154_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c6154_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c6154_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_c6154_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c6154_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_c6154_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c6154_row15_col0" class="data row15 col0" >Transform target</td>
#       <td id="T_c6154_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c6154_row16_col0" class="data row16 col0" >Transform target method</td>
#       <td id="T_c6154_row16_col1" class="data row16 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c6154_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_c6154_row17_col1" class="data row17 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c6154_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_c6154_row18_col1" class="data row18 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c6154_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_c6154_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c6154_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_c6154_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c6154_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_c6154_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c6154_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_c6154_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c6154_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c6154_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_c6154_row23_col1" class="data row23 col1" >b6ac</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_0e5e1 th {
#   text-align: left;
# }
# #T_0e5e1_row0_col0, #T_0e5e1_row1_col0, #T_0e5e1_row1_col1, #T_0e5e1_row1_col2, #T_0e5e1_row1_col3, #T_0e5e1_row1_col4, #T_0e5e1_row1_col5, #T_0e5e1_row1_col6, #T_0e5e1_row2_col0, #T_0e5e1_row2_col1, #T_0e5e1_row2_col2, #T_0e5e1_row2_col3, #T_0e5e1_row2_col4, #T_0e5e1_row2_col5, #T_0e5e1_row2_col6, #T_0e5e1_row3_col0, #T_0e5e1_row3_col1, #T_0e5e1_row3_col2, #T_0e5e1_row3_col3, #T_0e5e1_row3_col4, #T_0e5e1_row3_col5, #T_0e5e1_row3_col6, #T_0e5e1_row4_col0, #T_0e5e1_row4_col1, #T_0e5e1_row4_col2, #T_0e5e1_row4_col3, #T_0e5e1_row4_col4, #T_0e5e1_row4_col5, #T_0e5e1_row4_col6, #T_0e5e1_row5_col0, #T_0e5e1_row5_col1, #T_0e5e1_row5_col2, #T_0e5e1_row5_col3, #T_0e5e1_row5_col4, #T_0e5e1_row5_col5, #T_0e5e1_row5_col6, #T_0e5e1_row6_col0, #T_0e5e1_row6_col1, #T_0e5e1_row6_col2, #T_0e5e1_row6_col3, #T_0e5e1_row6_col4, #T_0e5e1_row6_col5, #T_0e5e1_row6_col6, #T_0e5e1_row7_col0, #T_0e5e1_row7_col1, #T_0e5e1_row7_col2, #T_0e5e1_row7_col3, #T_0e5e1_row7_col4, #T_0e5e1_row7_col5, #T_0e5e1_row7_col6, #T_0e5e1_row8_col0, #T_0e5e1_row8_col1, #T_0e5e1_row8_col2, #T_0e5e1_row8_col3, #T_0e5e1_row8_col4, #T_0e5e1_row8_col5, #T_0e5e1_row8_col6, #T_0e5e1_row9_col0, #T_0e5e1_row9_col1, #T_0e5e1_row9_col2, #T_0e5e1_row9_col3, #T_0e5e1_row9_col4, #T_0e5e1_row9_col5, #T_0e5e1_row9_col6, #T_0e5e1_row10_col0, #T_0e5e1_row10_col1, #T_0e5e1_row10_col2, #T_0e5e1_row10_col3, #T_0e5e1_row10_col4, #T_0e5e1_row10_col5, #T_0e5e1_row10_col6, #T_0e5e1_row11_col0, #T_0e5e1_row11_col1, #T_0e5e1_row11_col2, #T_0e5e1_row11_col3, #T_0e5e1_row11_col4, #T_0e5e1_row11_col5, #T_0e5e1_row11_col6, #T_0e5e1_row12_col0, #T_0e5e1_row12_col1, #T_0e5e1_row12_col2, #T_0e5e1_row12_col3, #T_0e5e1_row12_col4, #T_0e5e1_row12_col5, #T_0e5e1_row12_col6, #T_0e5e1_row13_col0, #T_0e5e1_row13_col1, #T_0e5e1_row13_col2, #T_0e5e1_row13_col3, #T_0e5e1_row13_col4, #T_0e5e1_row13_col5, #T_0e5e1_row13_col6, #T_0e5e1_row14_col0, #T_0e5e1_row14_col1, #T_0e5e1_row14_col2, #T_0e5e1_row14_col3, #T_0e5e1_row14_col4, #T_0e5e1_row14_col5, #T_0e5e1_row14_col6, #T_0e5e1_row15_col0, #T_0e5e1_row15_col1, #T_0e5e1_row15_col2, #T_0e5e1_row15_col3, #T_0e5e1_row15_col4, #T_0e5e1_row15_col5, #T_0e5e1_row15_col6, #T_0e5e1_row16_col0, #T_0e5e1_row16_col1, #T_0e5e1_row16_col2, #T_0e5e1_row16_col3, #T_0e5e1_row16_col4, #T_0e5e1_row16_col5, #T_0e5e1_row16_col6, #T_0e5e1_row17_col0, #T_0e5e1_row17_col1, #T_0e5e1_row17_col2, #T_0e5e1_row17_col3, #T_0e5e1_row17_col4, #T_0e5e1_row17_col5, #T_0e5e1_row17_col6, #T_0e5e1_row18_col0, #T_0e5e1_row18_col1, #T_0e5e1_row18_col2, #T_0e5e1_row18_col3, #T_0e5e1_row18_col4, #T_0e5e1_row18_col5, #T_0e5e1_row18_col6 {
#   text-align: left;
# }
# #T_0e5e1_row0_col1, #T_0e5e1_row0_col2, #T_0e5e1_row0_col3, #T_0e5e1_row0_col4, #T_0e5e1_row0_col5, #T_0e5e1_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0e5e1_row0_col7, #T_0e5e1_row1_col7, #T_0e5e1_row2_col7, #T_0e5e1_row3_col7, #T_0e5e1_row4_col7, #T_0e5e1_row5_col7, #T_0e5e1_row6_col7, #T_0e5e1_row7_col7, #T_0e5e1_row8_col7, #T_0e5e1_row9_col7, #T_0e5e1_row11_col7, #T_0e5e1_row12_col7, #T_0e5e1_row13_col7, #T_0e5e1_row14_col7, #T_0e5e1_row15_col7, #T_0e5e1_row16_col7, #T_0e5e1_row17_col7, #T_0e5e1_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0e5e1_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0e5e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e5e1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0e5e1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0e5e1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0e5e1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0e5e1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0e5e1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0e5e1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0e5e1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e5e1_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_0e5e1_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_0e5e1_row0_col1" class="data row0 col1" >0.0141</td>
#       <td id="T_0e5e1_row0_col2" class="data row0 col2" >0.0008</td>
#       <td id="T_0e5e1_row0_col3" class="data row0 col3" >0.0266</td>
#       <td id="T_0e5e1_row0_col4" class="data row0 col4" >0.9652</td>
#       <td id="T_0e5e1_row0_col5" class="data row0 col5" >0.0158</td>
#       <td id="T_0e5e1_row0_col6" class="data row0 col6" >0.0219</td>
#       <td id="T_0e5e1_row0_col7" class="data row0 col7" >0.2267</td>
#     </tr>
#     <tr>
#       <th id="T_0e5e1_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_0e5e1_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_0e5e1_row1_col1" class="data row1 col1" >0.0695</td>
#       <td id="T_0e5e1_row1_col2" class="data row1 col2" >0.0083</td>
#       <td id="T_0e5e1_row1_col3" class="data row1 col3" >0.0887</td>
#       <td id="T_0e5e1_row1_col4" class="data row1 col4" >0.6443</td>
#       <td id="T_0e5e1_row1_col5" class="data row1 col5" >0.0532</td>
#       <td id="T_0e5e1_row1_col6" class="data row1 col6" >0.1073</td>
#       <td id="T_0e5e1_row1_col7" class="data row1 col7" >0.2200</td>
#     </tr>
#     <tr>
#       <th id="T_0e5e1_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_0e5e1_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0e5e1_row2_col1" class="data row2 col1" >0.0791</td>
#       <td id="T_0e5e1_row2_col2" class="data row2 col2" >0.0098</td>
#       <td id="T_0e5e1_row2_col3" class="data row2 col3" >0.0979</td>
#       <td id="T_0e5e1_row2_col4" class="data row2 col4" >0.5850</td>
#       <td id="T_0e5e1_row2_col5" class="data row2 col5" >0.0593</td>
#       <td id="T_0e5e1_row2_col6" class="data row2 col6" >0.1284</td>
#       <td id="T_0e5e1_row2_col7" class="data row2 col7" >0.2300</td>
#     </tr>
#     <tr>
#       <th id="T_0e5e1_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_0e5e1_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_0e5e1_row3_col1" class="data row3 col1" >0.0987</td>
#       <td id="T_0e5e1_row3_col2" class="data row3 col2" >0.0153</td>
#       <td id="T_0e5e1_row3_col3" class="data row3 col3" >0.1234</td>
#       <td id="T_0e5e1_row3_col4" class="data row3 col4" >0.4114</td>
#       <td id="T_0e5e1_row3_col5" class="data row3 col5" >0.0770</td>
#       <td id="T_0e5e1_row3_col6" class="data row3 col6" >0.1713</td>
#       <td id="T_0e5e1_row3_col7" class="data row3 col7" >0.8400</td>
#     </tr>
#     <tr>
#       <th id="T_0e5e1_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_0e5e1_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_0e5e1_row4_col1" class="data row4 col1" >0.0992</td>
#       <td id="T_0e5e1_row4_col2" class="data row4 col2" >0.0154</td>
#       <td id="T_0e5e1_row4_col3" class="data row4 col3" >0.1240</td>
#       <td id="T_0e5e1_row4_col4" class="data row4 col4" >0.4049</td>
#       <td id="T_0e5e1_row4_col5" class="data row4 col5" >0.0773</td>
#       <td id="T_0e5e1_row4_col6" class="data row4 col6" >0.1717</td>
#       <td id="T_0e5e1_row4_col7" class="data row4 col7" >0.1067</td>
#     </tr>
#     <tr>
#       <th id="T_0e5e1_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_0e5e1_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0e5e1_row5_col1" class="data row5 col1" >0.0991</td>
#       <td id="T_0e5e1_row5_col2" class="data row5 col2" >0.0148</td>
#       <td id="T_0e5e1_row5_col3" class="data row5 col3" >0.1215</td>
#       <td id="T_0e5e1_row5_col4" class="data row5 col4" >0.4047</td>
#       <td id="T_0e5e1_row5_col5" class="data row5 col5" >0.0742</td>
#       <td id="T_0e5e

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_36365_row3_col0, #T_36365_row3_col1, #T_36365_row3_col2, #T_36365_row3_col3, #T_36365_row3_col4, #T_36365_row3_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_36365">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36365_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_36365_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_36365_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_36365_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_36365_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_36365_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36365_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36365_row0_col0" class="data row0 col0" >0.0240</td>
#       <td id="T_36365_row0_col1" class="data row0 col1" >0.0017</td>
#       <td id="T_36365_row0_col2" class="data row0 col2" >0.0408</td>
#       <td id="T_36365_row0_col3" class="data row0 col3" >0.9159</td>
#       <td id="T_36365_row0_col4" class="data row0 col4" >0.0223</td>
#       <td id="T_36365_row0_col5" class="data row0 col5" >0.0295</td>
#     </tr>
#     <tr>
#       <th id="T_36365_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36365_row1_col0" class="data row1 col0" >0.0116</td>
#       <td id="T_36365_row1_col1" class="data row1 col1" >0.0004</td>
#       <td id="T_36365_row1_col2" class="data row1 col2" >0.0211</td>
#       <td id="T_36365_row1_col3" class="data row1 col3" >0.9831</td>
#       <td id="T_36365_row1_col4" class="data row1 col4" >0.0140</td>
#       <td id="T_36365_row1_col5" class="data row1 col5" >0.0217</td>
#     </tr>
#     <tr>
#       <th id="T_36365_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36365_row2_col0" class="data row2 col0" >0.0101</td>
#       <td id="T_36365_row2_col1" class="data row2 col1" >0.0006</td>
#       <td id="T_36365_row2_col2" class="data row2 col2" >0.0236</td>
#       <td id="T_36365_row2_col3" class="data row2 col3" >0.9830</td>
#       <td id="T_36365_row2_col4" class="data row2 col4" >0.0148</td>
#       <td id="T_36365_row2_col5" class="data row2 col5" >0.0206</td>
#     </tr>
#     <tr>
#       <th id="T_36365_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_36365_row3_col0" class="data row3 col0" >0.0152</td>
#       <td id="T_36365_row3_col1" class="data row3 col1" >0.0009</td>
#       <td id="T_36365_row3_col2" class="data row3 col2" >0.0285</td>
#       <td id="T_36365_row3_col3" class="data row3 col3" >0.9607</td>
#       <td id="T_36365_row3_col4" class="data row3 col4" >0.0170</td>
#       <td id="T_36365_row3_col5" class="data row3 col5" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_36365_level0_row4" class="row_heading level0 row4" >Std</th>
#       <td id="T_36365_row4_col0" class="data row4 col0" >0.0062</td>
#       <td id="T_36365_row4_col1" class="data row4 col1" >0.0006</td>
#       <td id="T_36365_row4_col2" class="data row4 col2" >0.0088</td>
#       <td id="T_36365_row4_col3" class="data row4 col3" >0.0317</td>
#       <td id="T_36365_row4_col4" class="data row4 col4" >0.0037</td>
#       <td id="T_36365_row4_col5" class="data row4 col5" >0.0040</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# Too much error because of too little data points.

# %%
prediction = predict_model(tuned_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a1ed7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1ed7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a1ed7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a1ed7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a1ed7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a1ed7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a1ed7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a1ed7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1ed7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1ed7_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_a1ed7_row0_col1" class="data row0 col1" >0.2277</td>
#       <td id="T_a1ed7_row0_col2" class="data row0 col2" >0.2007</td>
#       <td id="T_a1ed7_row0_col3" class="data row0 col3" >0.4480</td>
#       <td id="T_a1ed7_row0_col4" class="data row0 col4" >0.9388</td>
#       <td id="T_a1ed7_row0_col5" class="data row0 col5" >0.0819</td>
#       <td id="T_a1ed7_row0_col6" class="data row0 col6" >0.0502</td>
#     </tr>
#   </tbody>
# </table>

# %%
s = setup(data=df, train_size=0.7, target='yield_tonnes_ha', fold=10, categorical_features=['national', 'subnational'], session_id=123)
# Out:
# <style type="text/css">
# #T_e7c20_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e7c20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7c20_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e7c20_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7c20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7c20_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e7c20_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7c20_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e7c20_row1_col1" class="data row1 col1" >yield_tonnes_ha</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7c20_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e7c20_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7c20_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e7c20_row3_col1" class="data row3 col1" >(15479, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7c20_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e7c20_row4_col1" class="data row4 col1" >(15479, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7c20_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e7c20_row5_col1" class="data row5 col1" >(10835, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7c20_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e7c20_row6_col1" class="data row6 col1" >(4644, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e7c20_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e7c20_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e7c20_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_e7c20_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e7c20_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_e7c20_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e7c20_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_e7c20_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e7c20_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_e7c20_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e7c20_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_e7c20_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e7c20_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_e7c20_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e7c20_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_e7c20_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e7c20_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_e7c20_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e7c20_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_e7c20_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e7c20_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_e7c20_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e7c20_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_e7c20_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e7c20_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_e7c20_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e7c20_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_e7c20_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e7c20_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_e7c20_row21_col1" class="data row21 col1" >dbf8</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_2cadd th {
#   text-align: left;
# }
# #T_2cadd_row0_col0, #T_2cadd_row1_col0, #T_2cadd_row1_col1, #T_2cadd_row1_col2, #T_2cadd_row1_col3, #T_2cadd_row1_col4, #T_2cadd_row1_col5, #T_2cadd_row1_col6, #T_2cadd_row2_col0, #T_2cadd_row2_col1, #T_2cadd_row2_col2, #T_2cadd_row2_col3, #T_2cadd_row2_col4, #T_2cadd_row2_col5, #T_2cadd_row2_col6, #T_2cadd_row3_col0, #T_2cadd_row3_col1, #T_2cadd_row3_col2, #T_2cadd_row3_col3, #T_2cadd_row3_col4, #T_2cadd_row3_col5, #T_2cadd_row3_col6, #T_2cadd_row4_col0, #T_2cadd_row4_col1, #T_2cadd_row4_col2, #T_2cadd_row4_col3, #T_2cadd_row4_col4, #T_2cadd_row4_col5, #T_2cadd_row4_col6, #T_2cadd_row5_col0, #T_2cadd_row5_col1, #T_2cadd_row5_col2, #T_2cadd_row5_col3, #T_2cadd_row5_col4, #T_2cadd_row5_col5, #T_2cadd_row5_col6, #T_2cadd_row6_col0, #T_2cadd_row6_col1, #T_2cadd_row6_col2, #T_2cadd_row6_col3, #T_2cadd_row6_col4, #T_2cadd_row6_col5, #T_2cadd_row6_col6, #T_2cadd_row7_col0, #T_2cadd_row7_col1, #T_2cadd_row7_col2, #T_2cadd_row7_col3, #T_2cadd_row7_col4, #T_2cadd_row7_col5, #T_2cadd_row7_col6, #T_2cadd_row8_col0, #T_2cadd_row8_col1, #T_2cadd_row8_col2, #T_2cadd_row8_col3, #T_2cadd_row8_col4, #T_2cadd_row8_col5, #T_2cadd_row8_col6, #T_2cadd_row9_col0, #T_2cadd_row9_col1, #T_2cadd_row9_col2, #T_2cadd_row9_col3, #T_2cadd_row9_col4, #T_2cadd_row9_col5, #T_2cadd_row9_col6, #T_2cadd_row10_col0, #T_2cadd_row10_col1, #T_2cadd_row10_col2, #T_2cadd_row10_col3, #T_2cadd_row10_col4, #T_2cadd_row10_col5, #T_2cadd_row10_col6, #T_2cadd_row11_col0, #T_2cadd_row11_col1, #T_2cadd_row11_col2, #T_2cadd_row11_col3, #T_2cadd_row11_col4, #T_2cadd_row11_col5, #T_2cadd_row11_col6, #T_2cadd_row12_col0, #T_2cadd_row12_col1, #T_2cadd_row12_col2, #T_2cadd_row12_col3, #T_2cadd_row12_col4, #T_2cadd_row12_col5, #T_2cadd_row12_col6, #T_2cadd_row13_col0, #T_2cadd_row13_col1, #T_2cadd_row13_col2, #T_2cadd_row13_col3, #T_2cadd_row13_col4, #T_2cadd_row13_col5, #T_2cadd_row13_col6, #T_2cadd_row14_col0, #T_2cadd_row14_col1, #T_2cadd_row14_col2, #T_2cadd_row14_col3, #T_2cadd_row14_col4, #T_2cadd_row14_col5, #T_2cadd_row14_col6, #T_2cadd_row15_col0, #T_2cadd_row15_col1, #T_2cadd_row15_col2, #T_2cadd_row15_col3, #T_2cadd_row15_col4, #T_2cadd_row15_col5, #T_2cadd_row15_col6, #T_2cadd_row16_col0, #T_2cadd_row16_col1, #T_2cadd_row16_col2, #T_2cadd_row16_col3, #T_2cadd_row16_col4, #T_2cadd_row16_col5, #T_2cadd_row16_col6, #T_2cadd_row17_col0, #T_2cadd_row17_col1, #T_2cadd_row17_col2, #T_2cadd_row17_col3, #T_2cadd_row17_col4, #T_2cadd_row17_col5, #T_2cadd_row17_col6, #T_2cadd_row18_col0, #T_2cadd_row18_col1, #T_2cadd_row18_col2, #T_2cadd_row18_col3, #T_2cadd_row18_col4, #T_2cadd_row18_col5, #T_2cadd_row18_col6 {
#   text-align: left;
# }
# #T_2cadd_row0_col1, #T_2cadd_row0_col2, #T_2cadd_row0_col3, #T_2cadd_row0_col4, #T_2cadd_row0_col5, #T_2cadd_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2cadd_row0_col7, #T_2cadd_row1_col7, #T_2cadd_row2_col7, #T_2cadd_row3_col7, #T_2cadd_row4_col7, #T_2cadd_row5_col7, #T_2cadd_row6_col7, #T_2cadd_row7_col7, #T_2cadd_row8_col7, #T_2cadd_row9_col7, #T_2cadd_row10_col7, #T_2cadd_row11_col7, #T_2cadd_row12_col7, #T_2cadd_row13_col7, #T_2cadd_row14_col7, #T_2cadd_row15_col7, #T_2cadd_row16_col7, #T_2cadd_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2cadd_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2cadd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cadd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2cadd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2cadd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2cadd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2cadd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2cadd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2cadd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2cadd_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cadd_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_2cadd_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_2cadd_row0_col1" class="data row0 col1" >0.0622</td>
#       <td id="T_2cadd_row0_col2" class="data row0 col2" >0.0251</td>
#       <td id="T_2cadd_row0_col3" class="data row0 col3" >0.1578</td>
#       <td id="T_2cadd_row0_col4" class="data row0 col4" >0.9905</td>
#       <td id="T_2cadd_row0_col5" class="data row0 col5" >0.0307</td>
#       <td id="T_2cadd_row0_col6" class="data row0 col6" >0.0272</td>
#       <td id="T_2cadd_row0_col7" class="data row0 col7" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_2cadd_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_2cadd_row1_col1" class="data row1 col1" >0.1281</td>
#       <td id="T_2cadd_row1_col2" class="data row1 col2" >0.0403</td>
#       <td id="T_2cadd_row1_col3" class="data row1 col3" >0.2003</td>
#       <td id="T_2cadd_row1_col4" class="data row1 col4" >0.9846</td>
#       <td id="T_2cadd_row1_col5" class="data row1 col5" >0.0590</td>
#       <td id="T_2cadd_row1_col6" class="data row1 col6" >0.0714</td>
#       <td id="T_2cadd_row1_col7" class="data row1 col7" >0.1450</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_2cadd_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_2cadd_row2_col1" class="data row2 col1" >0.1542</td>
#       <td id="T_2cadd_row2_col2" class="data row2 col2" >0.0595</td>
#       <td id="T_2cadd_row2_col3" class="data row2 col3" >0.2438</td>
#       <td id="T_2cadd_row2_col4" class="data row2 col4" >0.9773</td>
#       <td id="T_2cadd_row2_col5" class="data row2 col5" >0.0766</td>
#       <td id="T_2cadd_row2_col6" class="data row2 col6" >0.0969</td>
#       <td id="T_2cadd_row2_col7" class="data row2 col7" >0.9550</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_2cadd_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_2cadd_row3_col1" class="data row3 col1" >0.1589</td>
#       <td id="T_2cadd_row3_col2" class="data row3 col2" >0.0646</td>
#       <td id="T_2cadd_row3_col3" class="data row3 col3" >0.2540</td>
#       <td id="T_2cadd_row3_col4" class="data row3 col4" >0.9754</td>
#       <td id="T_2cadd_row3_col5" class="data row3 col5" >0.0757</td>
#       <td id="T_2cadd_row3_col6" class="data row3 col6" >0.0938</td>
#       <td id="T_2cadd_row3_col7" class="data row3 col7" >1.8120</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_2cadd_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2cadd_row4_col1" class="data row4 col1" >0.1765</td>
#       <td id="T_2cadd_row4_col2" class="data row4 col2" >0.0686</td>
#       <td id="T_2cadd_row4_col3" class="data row4 col3" >0.2617</td>
#       <td id="T_2cadd_row4_col4" class="data row4 col4" >0.9738</td>
#       <td id="T_2cadd_row4_col5" class="data row4 col5" >0.0812</td>
#       <td id="T_2cadd_row4_col6" class="data row4 col6" >0.1101</td>
#       <td id="T_2cadd_row4_col7" class="data row4 col7" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_2cadd_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_2cadd_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_2cadd_row5_col1" class="data row5 col1" >0.2114</td>
#       <td id="T_2cadd_row5_col2" class="data row5 col2" >0.1093</td>
#       <td id="T_2cadd_row5_col3" class="data row5 col3" >0.3301</td>
#       <td id="T_2cadd_row5_col4" class="data row5 col4" >0.9583</td>
#       <td id="T_2cadd_row5_col5" class="data row5 col5" >0.0992</td>
#       <td id="

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_48ca9_row10_col0, #T_48ca9_row10_col1, #T_48ca9_row10_col2, #T_48ca9_row10_col3, #T_48ca9_row10_col4, #T_48ca9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_48ca9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48ca9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_48ca9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_48ca9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_48ca9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_48ca9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_48ca9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48ca9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48ca9_row0_col0" class="data row0 col0" >0.0594</td>
#       <td id="T_48ca9_row0_col1" class="data row0 col1" >0.0208</td>
#       <td id="T_48ca9_row0_col2" class="data row0 col2" >0.1443</td>
#       <td id="T_48ca9_row0_col3" class="data row0 col3" >0.9920</td>
#       <td id="T_48ca9_row0_col4" class="data row0 col4" >0.0256</td>
#       <td id="T_48ca9_row0_col5" class="data row0 col5" >0.0274</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48ca9_row1_col0" class="data row1 col0" >0.0665</td>
#       <td id="T_48ca9_row1_col1" class="data row1 col1" >0.0271</td>
#       <td id="T_48ca9_row1_col2" class="data row1 col2" >0.1646</td>
#       <td id="T_48ca9_row1_col3" class="data row1 col3" >0.9912</td>
#       <td id="T_48ca9_row1_col4" class="data row1 col4" >0.0285</td>
#       <td id="T_48ca9_row1_col5" class="data row1 col5" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48ca9_row2_col0" class="data row2 col0" >0.0599</td>
#       <td id="T_48ca9_row2_col1" class="data row2 col1" >0.0308</td>
#       <td id="T_48ca9_row2_col2" class="data row2 col2" >0.1755</td>
#       <td id="T_48ca9_row2_col3" class="data row2 col3" >0.9884</td>
#       <td id="T_48ca9_row2_col4" class="data row2 col4" >0.0288</td>
#       <td id="T_48ca9_row2_col5" class="data row2 col5" >0.0259</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48ca9_row3_col0" class="data row3 col0" >0.0585</td>
#       <td id="T_48ca9_row3_col1" class="data row3 col1" >0.0179</td>
#       <td id="T_48ca9_row3_col2" class="data row3 col2" >0.1340</td>
#       <td id="T_48ca9_row3_col3" class="data row3 col3" >0.9932</td>
#       <td id="T_48ca9_row3_col4" class="data row3 col4" >0.0259</td>
#       <td id="T_48ca9_row3_col5" class="data row3 col5" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48ca9_row4_col0" class="data row4 col0" >0.0602</td>
#       <td id="T_48ca9_row4_col1" class="data row4 col1" >0.0224</td>
#       <td id="T_48ca9_row4_col2" class="data row4 col2" >0.1497</td>
#       <td id="T_48ca9_row4_col3" class="data row4 col3" >0.9918</td>
#       <td id="T_48ca9_row4_col4" class="data row4 col4" >0.0270</td>
#       <td id="T_48ca9_row4_col5" class="data row4 col5" >0.0233</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48ca9_row5_col0" class="data row5 col0" >0.0518</td>
#       <td id="T_48ca9_row5_col1" class="data row5 col1" >0.0165</td>
#       <td id="T_48ca9_row5_col2" class="data row5 col2" >0.1286</td>
#       <td id="T_48ca9_row5_col3" class="data row5 col3" >0.9929</td>
#       <td id="T_48ca9_row5_col4" class="data row5 col4" >0.0266</td>
#       <td id="T_48ca9_row5_col5" class="data row5 col5" >0.0257</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48ca9_row6_col0" class="data row6 col0" >0.0599</td>
#       <td id="T_48ca9_row6_col1" class="data row6 col1" >0.0161</td>
#       <td id="T_48ca9_row6_col2" class="data row6 col2" >0.1270</td>
#       <td id="T_48ca9_row6_col3" class="data row6 col3" >0.9934</td>
#       <td id="T_48ca9_row6_col4" class="data row6 col4" >0.0293</td>
#       <td id="T_48ca9_row6_col5" class="data row6 col5" >0.0252</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_48ca9_row7_col0" class="data row7 col0" >0.0589</td>
#       <td id="T_48ca9_row7_col1" class="data row7 col1" >0.0217</td>
#       <td id="T_48ca9_row7_col2" class="data row7 col2" >0.1474</td>
#       <td id="T_48ca9_row7_col3" class="data row7 col3" >0.9915</td>
#       <td id="T_48ca9_row7_col4" class="data row7 col4" >0.0276</td>
#       <td id="T_48ca9_row7_col5" class="data row7 col5" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_48ca9_row8_col0" class="data row8 col0" >0.0653</td>
#       <td id="T_48ca9_row8_col1" class="data row8 col1" >0.0287</td>
#       <td id="T_48ca9_row8_col2" class="data row8 col2" >0.1693</td>
#       <td id="T_48ca9_row8_col3" class="data row8 col3" >0.9894</td>
#       <td id="T_48ca9_row8_col4" class="data row8 col4" >0.0347</td>
#       <td id="T_48ca9_row8_col5" class="data row8 col5" >0.0275</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_48ca9_row9_col0" class="data row9 col0" >0.0656</td>
#       <td id="T_48ca9_row9_col1" class="data row9 col1" >0.0258</td>
#       <td id="T_48ca9_row9_col2" class="data row9 col2" >0.1608</td>
#       <td id="T_48ca9_row9_col3" class="data row9 col3" >0.9900</td>
#       <td id="T_48ca9_row9_col4" class="data row9 col4" >0.0360</td>
#       <td id="T_48ca9_row9_col5" class="data row9 col5" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_48ca9_row10_col0" class="data row10 col0" >0.0606</td>
#       <td id="T_48ca9_row10_col1" class="data row10 col1" >0.0228</td>
#       <td id="T_48ca9_row10_col2" class="data row10 col2" >0.1501</td>
#       <td id="T_48ca9_row10_col3" class="data row10 col3" >0.9914</td>
#       <td id="T_48ca9_row10_col4" class="data row10 col4" >0.0290</td>
#       <td id="T_48ca9_row10_col5" class="data row10 col5" >0.0264</td>
#     </tr>
#     <tr>
#       <th id="T_48ca9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_48ca9_row11_col0" class="data row11 col0" >0.0041</td>
#       <td id="T_48ca9_row11_col1" class="data row11 col1" >0.0049</td>
#       <td id="T_48ca9_row11_col2" class="data row11 col2" >0.0162</td>
#       <td id="T_48ca9_row11_col3" class="data row11 col3" >0.0016</td>
#       <td id="T_48ca9_row11_col4" class="data row11 col4" >0.0034</td>
#       <td id="T_48ca9_row11_col5" class="data row11 col5" >0.0020</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(best_model, 'crops_jeffrey')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['hectares_ha', 'production_tonnes',
#                                               'year'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['national', 'subnational'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['national'],
#                                      transformer=OneHotEncoder(cols=['national'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['subnational'],
#                                      transformer=TargetEncoder(cols=['subnational'],
#                                                                handle_missing='return_nan'))),
#                  ('trained_model', KNeighborsRegressor(n_jobs=-1))]),
#  'crops_jeffrey.pkl')
