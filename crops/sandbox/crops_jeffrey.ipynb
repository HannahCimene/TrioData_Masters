# %% [markdown]
# In this notebook I tried to apply timeseries forecasting, but due to many duplicate time values per country I was not able to pull it off.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.time_series import *
from pycaret.classification import plot_model

# %%
file = pd.ExcelFile("food-twentieth-century-crop-statistics-1900-2017-xlsx.xlsx")
df = file.parse('CropStats')
df = df.set_index(df.columns[0])
df.index.name = None

# %% [markdown]
# ## Clean Data
# Columns with too many null values or meaningless information are dropped.
# Columns with unclear names are renamed.
# For the subnational column null values are filled up with corresponding values from the national column.
# For yield, production, and hectares, if one of them is null but the others in the same row are not, the null one can be calculated. Here we need to pay attention to not divide by 0.
# We chose to focus on wheat, so we will be filtering the df accordingly.
# We also added columns with logarithmic transformations for yield, production, and hectares.

# %%
df.drop(['admin2', 'notes', 'Harvest_year'], axis=1, inplace=True)
df.rename(columns = {'admin0': 'national', 'admin1': 'subnational', 'hectares (ha)': 'hectares_ha', 'production (tonnes)': 'production_tonnes', 'yield(tonnes/ha)': 'yield_tonnes_ha'}, inplace=True)
df.loc[df['subnational'].isna(), 'subnational'] = df['national']
# Calculate yield
mask = df['yield_tonnes_ha'].isna() & ~df['production_tonnes'].isna() & ~df['hectares_ha'].isna() & df['hectares_ha'] != 0
df.loc[mask, 'yield_tonnes_ha'] = df['production_tonnes'] / df['hectares_ha']
df.dropna(subset=['yield_tonnes_ha'], inplace=True)
# Calculate production
mask = df['production_tonnes'].isna() & ~df['yield_tonnes_ha'].isna() & ~df['hectares_ha'].isna()
df.loc[mask, 'production_tonnes'] = df['yield_tonnes_ha'] * df['hectares_ha']
df.dropna(subset=['production_tonnes'], inplace=True)
# Calculate hectares
mask = df['hectares_ha'].isna() & ~df['yield_tonnes_ha'].isna() & ~df['production_tonnes'].isna()
df.loc[mask, 'hectares_ha'] = df['yield_tonnes_ha'] * df['production_tonnes']
df.dropna(subset=['hectares_ha'], inplace=True)
# The columns we just adapted just changed into objects, let's make them floats again
df['hectares_ha'] = df['hectares_ha'].astype(float)
df['production_tonnes'] = df['production_tonnes'].astype(float)
df['yield_tonnes_ha'] = df['yield_tonnes_ha'].astype(float)
# Filter for wheat
df = df[df['crop'] == 'wheat']
# Remove the crop column
df.drop('crop', axis=1, inplace =True)
# Logarithmic transformations
# df['log_yield'] = np.log1p(df['yield_tonnes_ha'])
# df['log_hectares'] = np.log1p(df['production_tonnes'])
# df['log_production'] = np.log1p(df['hectares_ha'])

# df = df.drop(['log_yield', 'log_hectares', 'log_production'], axis=1, inplace=True)

# %%
df[df['national'] == 'Belgium']
# Out:
#     national subnational  hectares_ha  production_tonnes  year  \
# 175  Belgium     Belgium     212139.0          753093.45  1961
# 176  Belgium     Belgium     212221.0          876472.73  1962
# 177  Belgium     Belgium     201443.0          743324.67  1963
# 178  Belgium     Belgium     217656.0          916331.76  1964
# 179  Belgium     Belgium     229353.0          864660.81  1965
# 180  Belgium     Belgium     231643.0          604588.23  1966
# 181  Belgium     Belgium     216676.0         1001043.12  1967
# 182  Belgium     Belgium     220347.0          969526.80  1968
# 183  Belgium     Belgium     215759.0          888927.08  1969
# 184  Belgium     Belgium     198233.0          876189.86  1970
# 185  Belgium     Belgium     212702.0          999699.40  1971
# 186  Belgium     Belgium     222877.0         1023005.43  1972
# 187  Belgium     Belgium     211923.0         1093522.68  1973
# 188  Belgium     Belgium     198483.0         1065853.71  1974
# 189  Belgium     Belgium     190323.0          786033.99  1975
# 190  Belgium     Belgium     211899.0          989568.33  1976
# 191  Belgium     Belgium     193782.0          817760.04  1977
# 192  Belgium     Belgium     194479.0         1046297.02  1978
# 193  Belgium     Belgium     197743.0         1032218.46  1979
# 194  Belgium     Belgium     196499.0          931405.26  1980
# 195  Belgium     Belgium     173113.0          915767.77  1981
# 196  Belgium     Belgium     182944.0         1101322.88  1982
# 197  Belgium     Belgium     203207.0         1085125.38  1983
# 198  Belgium     Belgium     194340.0         1360380.00  1984
# 199  Belgium     Belgium     194409.0         1238385.33  1985
# 200  Belgium     Belgium     196473.0         1349769.51  1986
# 201  Belgium     Belgium     192866.0         1081978.26  1987
# 202  Belgium     Belgium     202268.0         1355195.60  1988
# 203  Belgium     Belgium     219000.0         1511100.00  1989
# 204  Belgium     Belgium     222000.0         1363080.00  1990
# 205  Belgium     Belgium     215000.0         1459850.00  1991
# 206  Belgium     Belgium     216000.0         1419120.00  1992
# 207  Belgium     Belgium     212000.0         1534880.00  1993
# 208  Belgium     Belgium     212000.0         1503080.00  1994
# 209  Belgium     Belgium     218400.0         1603056.00  1995
# 210  Belgium     Belgium     214000.0         1936700.00  1996
# 211  Belgium     Belgium     216500.0         1729835.00  1997
# 212  Belgium     Belgium     222000.0         1789320.00  1998
# 213  Belgium     Belgium     188800.0         1621792.00  1999
# 214  Belgium     Belgium     213100.0         1694145.00  2000
# 215  Belgium     Belgium     181100.0         1457855.00  2001
# 216  Belgium     Belgium     202400.0         1675872.00  2002
# 217  Belgium     Belgium     191216.0         1623423.84  2003
# 218  Belgium     Belgium     213035.0         1913054.30  2004
# 219  Belgium     Belgium     213748.0         1799758.16  2005
# 220  Belgium     Belgium     201330.0         1644866.10  2006
# 221  Belgium     Belgium     199897.0         1565193.51  2007
# 222  Belgium     Belgium     211270.0         1833823.60  2008
# 223  Belgium     Belgium     201768.0         1910742.96  2009
# 224  Belgium     Belgium     209532.0         1848072.24  2010
# 225  Belgium     Belgium     200813.0         1676788.55  2011
# 226  Belgium     Belgium     217060.0         1801598.00  2012
# 227  Belgium     Belgium     201854.0         1803550.00  2013
# 228  Belgium     Belgium     211900.0         1994600.00  2014
# 229  Belgium     Belgium     201628.0         2019347.00  2015
# 230  Belgium     Belgium     206284.0         1400074.00  2016
# 231  Belgium     Belgium     197592.0         1702721.00  2017
#
#      yield_tonnes_ha
# 175           3.5500
# 176           4.1300
# 177           3.6900
# 178           4.2100
# 179           3.7700
# 180           2.6100
# 181           4.6200
# 182           4.4000
# 183           4.1200
# 184           4.4200
# 185           4.7000
# 186           4.5900
# 187           5.1600
# 188           5.3700
# 189           4.1300
# 190           4.6700
# 191           4.2200
# 192           5.3800
# 193           5.2200
# 194           4.7400
# 195           5.2900
# 196           6.0200
# 197           5.3400
# 198           7.0000
# 199           6.3700
# 200           6.8700
# 201           5.6100
# 202           6.7000
# 203           6.9000
# 204           6.1400
# 205           6.7900
# 206           6.5700
# 207           7.2400
# 208           7.0900
# 209           7.3400
# 210           9.0500
# 211           7.9900
# 212           8.0600
# 213           8.5900
# 214           7.9500
# 215           8.0500
# 216           8.2800
# 217           8.4900
# 218           8.9800
# 219           8.4200
# 220           8.1700
# 221           7.8300
# 222           8.6800
# 223           9.4700
# 224           8.8200
# 225           8.3500
# 226           8.3000
# 227           8.9349
# 228           9.4129
# 229          10.0152
# 230           6.7871
# 231           8.6174

# %%
df.loc[:, "year"] = pd.to_datetime(df["year"], format='%Y')
# df = df.set_index('year')
# df.index = df.index.to_period(freq='A')
belgium = df[df['national'] == 'Belgium']
belgium.head()
# Out:
#     national subnational  hectares_ha  production_tonnes       year  \
# 175  Belgium     Belgium     212139.0          753093.45 1961-01-01
# 176  Belgium     Belgium     212221.0          876472.73 1962-01-01
# 177  Belgium     Belgium     201443.0          743324.67 1963-01-01
# 178  Belgium     Belgium     217656.0          916331.76 1964-01-01
# 179  Belgium     Belgium     229353.0          864660.81 1965-01-01
#
#      yield_tonnes_ha
# 175             3.55
# 176             4.13
# 177             3.69
# 178             4.21
# 179             3.77

# %%
X = belgium[['year', 'yield_tonnes_ha', 'production_tonnes', 'hectares_ha']]
belgium.describe()
# Out:
#          hectares_ha  production_tonnes  yield_tonnes_ha
# count      57.000000       5.700000e+01        57.000000
# mean   206263.631579       1.343943e+06         6.530132
# std     12097.673802       3.940915e+05         1.903033
# min    173113.000000       6.045882e+05         2.610000
# 25%    197743.000000       9.996994e+05         4.700000
# 50%    209532.000000       1.363080e+06         6.787100
# 75%    215000.000000       1.676789e+06         8.280000
# max    231643.000000       2.019347e+06        10.015200

# %%
exp_reg = setup(data=X, fold=3, target='yield_tonnes_ha' , fh=5, session_id=123, index='year')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca7ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca7ed_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ca7ed_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca7ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca7ed_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_ca7ed_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca7ed_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ca7ed_row1_col1" class="data row1 col1" >yield_tonnes_ha</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca7ed_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_ca7ed_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca7ed_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_ca7ed_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca7ed_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ca7ed_row4_col1" class="data row4 col1" >(57, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ca7ed_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ca7ed_row5_col1" class="data row5 col1" >(57, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ca7ed_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ca7ed_row6_col1" class="data row6 col1" >(52, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ca7ed_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ca7ed_row7_col1" class="data row7 col1" >(5, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ca7ed_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_ca7ed_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ca7ed_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_ca7ed_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ca7ed_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_ca7ed_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ca7ed_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_ca7ed_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ca7ed_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_ca7ed_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ca7ed_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_ca7ed_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ca7ed_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_ca7ed_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ca7ed_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_ca7ed_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ca7ed_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_ca7ed_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ca7ed_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_ca7ed_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ca7ed_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_ca7ed_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ca7ed_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_ca7ed_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ca7ed_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_ca7ed_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ca7ed_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_ca7ed_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ca7ed_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_ca7ed_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ca7ed_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_ca7ed_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ca7ed_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_ca7ed_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_ca7ed_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_ca7ed_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_ca7ed_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_ca7ed_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_ca7ed_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_ca7ed_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_ca7ed_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_ca7ed_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_ca7ed_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_ca7ed_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ca7ed_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_ca7ed_row30_col0" class="data row30 col0"

# %%
best_model = compare_models()

# %%
tuned_model = tune_model(best_model)
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                                         19:46:17
# Status                           Searching Hyperparameters
# Estimator  K Neighbors w/ Cond. Deseasonalize & Detrending
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\externals\loky\process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py", line 589, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\utils\time_series\forecasting\model_selection.py", line 178, in _fit_and_score
#     y_pred, lower, upper = get_predictions_with_intervals(
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\utils\time_series\forecasting\__init__.py", line 110, in get_predictions_with_intervals
#     y_pred = forecaster.predict(fh=fh, X=X)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_base.py", line 404, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\compose\_pipeline.py", line 511, in _predict
#     return self.forecaster_.predict(fh, X)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_base.py", line 404, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\compose\_pipeline.py", line 1006, in _predict
#     y_pred = self.forecaster_.predict(fh=fh, X=X)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_base.py", line 404, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\containers\models\time_series.py", line 2685, in _predict
#     y = self._forecaster.predict(fh=fh, X=X)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_base.py", line 404, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\compose\_pipeline.py", line 1006, in _predict
#     y_pred = self.forecaster_.predict(fh=fh, X=X)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_base.py", line 404, in predict
#     y_pred = self._predict(fh=fh, X=X_inner)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_sktime.py", line 30, in _predict
#     y_pred = self._predict_fixed_cutoff(
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\base\_sktime.py", line 74, in _predict_fixed_cutoff
#     y_pred = self._predict_last_window(
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sktime\forecasting\compose\_reduce.py", line 878, in _predict_last_window
#     y_pred_vector = self.estimator_.predict(X_last)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sklearn\neighbors\_regression.py", line 236, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\sklearn\neighbors\_base.py", line 810, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 36, n_neighbors = 46
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\Jeffr\Documents\School\IT\Cloud AI\crops_jeffrey.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jeffr/Documents/School/IT/Cloud%20AI/crops_jeffrey.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> tuned_model = tune_model(best_model)
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\time_series\forecasting\functional.py:1052, in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_algorithm, choose_better, fit_kwargs, return_tuner, verbose, tuner_verbose, **kwargs)
#     943 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     944 def tune_model(
#     945     estimator,
#    (...)
#     958     **kwargs,
#     959 ):
#     960     """
#     961     This function tunes the hyperparameters of a given estimator. The output of
#     962     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1049
#    1050     """
# -> 1052     return _CURRENT_EXPERIMENT.tune_model(
#    1053         estimator=estimator,
#    1054         fold=fold,
#    1055         round=round,
#    1056         n_iter=n_iter,
#    1057         custom_grid=custom_grid,
#    1058         optimize=optimize,
#    1059         custom_scorer=custom_scorer,
#    1060         search_algorithm=search_algorithm,
#    1061         choose_better=choose_better,
#    1062         fit_kwargs=fit_kwargs,
#    1063         return_tuner=return_tuner,
#    1064         verbose=verbose,
#    1065         tuner_verbose=tuner_verbose,
#    1066         **kwargs,
#    1067     )
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\time_series\forecasting\oop.py:3169, in TSForecastingExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_algorithm, choose_better, fit_kwargs, return_tuner, verbose, tuner_verbose, **kwargs)
#    3164         raise NotImplementedError(
#    3165             f"Search type '{search_algorithm}' is not supported"
#    3166         )
#    3168 additional_scorer_kwargs = self.get_additional_scorer_kwargs()
# -> 3169 model_grid.fit(
#    3170     y=data_y,
#    3171     X=data_X,
#    3172     additional_scorer_kwargs=additional_scorer_kwargs,
#    3173     **fit_kwargs,
#    3174 )
#    3176 best_params = model_grid.best_params_
#    3177 self.logger.info(f"best_params: {best_params}")
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\utils\time_series\forecasting\model_selection.py:528, in BaseGridSearch.fit(self, y, X, additional_scorer_kwargs, **fit_params)
#     523     results = self._format_results(
#     524         all_candidate_params, scorers, all_out, n_splits
#     525     )
#     526     return results
# --> 528 self._run_search(evaluate_candidates)
#     530 self.best_index_ = results["rank_test_%s" % refit_metric].argmin()
#     531 self.best_score_ = results["mean_test_%s" % refit_metric][self.best_index_]
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\utils\time_series\forecasting\model_selection.py:730, in ForecastingRandomizedSearchCV._run_search(self, evaluate_candidates)
#     728 def _run_search(self, evaluate_candidates):
#     729     """Search n_iter candidates from param_distributions"""
# --> 730     return evaluate_candidates(
#     731         ParameterSampler(
#     732             self.param_distributions, self.n_iter, random_state=self.random_state
#     733         )
#     734     )
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\utils\time_series\forecasting\model_selection.py:492, in BaseGridSearch.fit.<locals>.evaluate_candidates(candidate_params)
#     484     print(
#     485         f"Fitting {n_splits} folds for each of {n_candidates} "
#     486         f"candidates, totalling {n_candidates * n_splits} fits"
#     487     )
#     489 parallel = Parallel(
#     490     n_jobs=self.n_jobs, verbose=self.verbose, pre_dispatch=self.pre_dispatch
#     491 )
# --> 492 out = parallel(
#     493     delayed(_fit_and_score)(
#     494         pipeline=clone(base_pipeline),
#     495         y=y,
#     496         X=X,
#     497         scoring=scorers,
#     498         train=train,
#     499         test=test,
#     500         parameters=parameters,
#     501         fit_params=fit_params,
#     502         return_train_score=self.return_train_score,
#     503         alpha=self.alpha,
#     504         coverage=self.coverage,
#     505         error_score=self.error_score,
#     506         **additional_scorer_kwargs,
#     507     )
#     508     for parameters in candidate_params
#     509     for train, test in get_folds(cv, y)
#     510 )
#     512 if len(out) < 1:
#     513     raise ValueError(
#     514         "No fits were performed. "
#     515         "Was the CV iterator empty? "
#     516         "Were there no candidates?"
#     517     )
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\joblib\parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 36, n_neighbors = 46

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best_model, fh= np.arange(50, 60))
# Out:
#        y_pred
# 2057  14.1417
# 2058  14.2608
# 2059  14.3799
# 2060  14.4990
# 2061  14.6182
# 2062  14.7373
# 2063  14.8564
# 2064  14.9755
# 2065  15.0946
# 2066  15.2137

# %% [markdown]
# <b>USA</b>

# %%
france = df[df['national'] == 'France']
france.describe()
# Out:
#          hectares_ha  production_tonnes  yield_tonnes_ha
# count    2589.000000       2.589000e+03      2589.000000
# mean   222227.110154       7.732209e+05         3.336880
# std    167633.970095       9.459215e+05         2.311682
# min        63.000000       1.656000e+02         0.300000
# 25%     84400.000000       1.718580e+05         1.376519
# 50%    202503.000000       4.497760e+05         2.437463
# 75%    329805.000000       9.068510e+05         5.160816
# max    883700.000000       6.129295e+06         9.932212

# %%
X = france[['year', 'yield_tonnes_ha', 'production_tonnes', 'hectares_ha']]

# %%
france.year.value_counts()
# Out:
# 1959-01-01    22
# 1974-01-01    22
# 1986-01-01    22
# 1985-01-01    22
# 1984-01-01    22
#               ..
# 1941-01-01    21
# 1942-01-01    21
# 1944-01-01    21
# 1900-01-01    21
# 1943-01-01    20
# Name: year, Length: 119, dtype: int64

# %%
exp_reg = setup(data=X, fold=3, target='yield_tonnes_ha' , fh=5, session_id=123, index='year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Jeffr\Documents\School\IT\Cloud AI\crops_jeffrey.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jeffr/Documents/School/IT/Cloud%20AI/crops_jeffrey.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> exp_reg = setup(data=X, fold=3, target='yield_tonnes_ha' , fh=5, session_id=123, index='year')
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\time_series\forecasting\functional.py:590, in setup(data, data_func, target, index, ignore_features, numeric_imputation_target, numeric_imputation_exogenous, transform_target, transform_exogenous, fe_target_rr, fe_exogenous, scale_target, scale_exogenous, fold_strategy, fold, fh, hyperparameter_split, seasonal_period, ignore_seasonality_test, sp_detection, max_sp_to_consider, remove_harmonics, harmonic_order_method, num_sps_to_use, seasonality_type, point_alpha, coverage, enforce_exogenous, n_jobs, use_gpu, custom_pipeline, html, session_id, system_log, log_experiment, experiment_name, log_plots, log_profile, log_data, verbose, profile, profile_kwargs, fig_kwargs)
#     588 exp = _EXPERIMENT_CLASS()
#     589 set_current_experiment(exp)
# --> 590 return exp.setup(
#     591     data=data,
#     592     data_func=data_func,
#     593     target=target,
#     594     index=index,
#     595     ignore_features=ignore_features,
#     596     numeric_imputation_target=numeric_imputation_target,
#     597     numeric_imputation_exogenous=numeric_imputation_exogenous,
#     598     transform_target=transform_target,
#     599     transform_exogenous=transform_exogenous,
#     600     scale_target=scale_target,
#     601     scale_exogenous=scale_exogenous,
#     602     fe_target_rr=fe_target_rr,
#     603     fe_exogenous=fe_exogenous,
#     604     fold_strategy=fold_strategy,
#     605     fold=fold,
#     606     fh=fh,
#     607     hyperparameter_split=hyperparameter_split,
#     608     seasonal_period=seasonal_period,
#     609     ignore_seasonality_test=ignore_seasonality_test,
#     610     sp_detection=sp_detection,
#     611     max_sp_to_consider=max_sp_to_consider,
#     612     remove_harmonics=remove_harmonics,
#     613     harmonic_order_method=harmonic_order_method,
#     614     num_sps_to_use=num_sps_to_use,
#     615     seasonality_type=seasonality_type,
#     616     point_alpha=point_alpha,
#     617     coverage=coverage,
#     618     enforce_exogenous=enforce_exogenous,
#     619     n_jobs=n_jobs,
#     620     use_gpu=use_gpu,
#     621     custom_pipeline=custom_pipeline,
#     622     html=html,
#     623     session_id=session_id,
#     624     system_log=system_log,
#     625     log_experiment=log_experiment,
#     626     experiment_name=experiment_name,
#     627     log_plots=log_plots,
#     628     log_profile=log_profile,
#     629     log_data=log_data,
#     630     verbose=verbose,
#     631     profile=profile,
#     632     profile_kwargs=profile_kwargs,
#     633     fig_kwargs=fig_kwargs,
#     634 )
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\time_series\forecasting\oop.py:2095, in TSForecastingExperiment.setup(self, data, data_func, target, index, ignore_features, numeric_imputation_target, numeric_imputation_exogenous, transform_target, transform_exogenous, scale_target, scale_exogenous, fe_target_rr, fe_exogenous, fold_strategy, fold, fh, hyperparameter_split, seasonal_period, ignore_seasonality_test, sp_detection, max_sp_to_consider, remove_harmonics, harmonic_order_method, num_sps_to_use, seasonality_type, point_alpha, coverage, enforce_exogenous, n_jobs, use_gpu, custom_pipeline, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, profile, profile_kwargs, fig_kwargs)
#    2091 # Features to be ignored (are not read by self.dataset, self.X, etc...)
#    2092 self._fxs = {"Ignore": ignore_features or []}
#    2094 (
# -> 2095     self._initialize_setup(
#    2096         n_jobs=n_jobs,
#    2097         use_gpu=use_gpu,
#    2098         html=html,
#    2099         session_id=session_id,
#    2100         system_log=system_log,
#    2101         log_experiment=log_experiment,
#    2102         experiment_name=experiment_name,
#    2103         memory=True,
#    2104         verbose=verbose,
#    2105     )
#    2106     ._check_clean_and_set_data(data)
#    2107     ._check_and_clean_index(index=index, seasonal_period=seasonal_period)
#    2108     ._check_and_set_targets(target=target)
#    2109     ._set_exogenous_names()
#    2110     ._check_and_set_forecasting_types()
#    2111     ._check_and_set_fh(fh=fh)
#    2112     ._set_point_alpha_intervals_enforce_pi(
#    2113         point_alpha=point_alpha, coverage=coverage
#    2114     )
#    2115     ._setup_train_test_split()
#    2116     ._set_fold_generator()
#    2117     ._set_should_preprocess_data()
#    2118     ._set_missingness()
#    2119     ._initialize_pipeline()
#    2120     ##################################################################
#    2121     # Do these after the preprocessing pipeline has been setup.
#    2122     # Since the model will see transformed data, these parameters
#    2123     # should also be derived from the transformed data.
#    2124     ##################################################################
#    2125     ._check_and_set_seasonal_period()
#    2126     ._set_seasonal_type(seasonality_type=seasonality_type)
#    2127     ._perform_setup_eda()
#    2128     ._setup_display_container()
#    2129     ._profile(profile, profile_kwargs)
#    2130     ._set_exp_model_engines(
#    2131         container_default_engines=get_container_default_engines(),
#    2132         engine=engine,
#    2133     )
#    2134     ._set_all_models()
#    2135     ._set_all_metrics()
#    2136 )
#    2138 runtime = np.array(time.time() - runtime_start).round(2)
#    2140 self._set_up_logging(
#    2141     runtime,
#    2142     log_data,
#    2143     log_profile,
#    2144     experiment_custom_tags=experiment_custom_tags,
#    2145 )
#
# File c:\Users\Jeffr\Documents\School\IT\Cloud AI\venv\lib\site-packages\pycaret\time_series\forecasting\oop.py:537, in TSForecastingExperiment._check_and_clean_index(self, index, seasonal_period)
#     535 # Data must not have duplicate indices ----
#     536 if len(self.data.index) != len(set(self.data.index)):
# --> 537     raise ValueError(
#     538         "Index may not have duplicate values! Please check and correct before passing to pycaret"
#     539     )
#     541 # Check Index Type ----
#     542 allowed_freq_index_types = (pd.PeriodIndex, pd.DatetimeIndex)
#
# ValueError: Index may not have duplicate values! Please check and correct before passing to pycaret
