# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

df = pd.read_excel("../data/titanic3.xls")

# change names
df = df.rename(columns={'pclass': 'Passenger Class', 'survived': 'Survived', 'age': 'Age', 'sibsp': 'Siblings/spouses aboard', 'parch': 'Parents/children aboard', 'fare': 'Passenger fare', 'embarked': 'Port of Embarkation', 'home.dest': 'Home/Destination'})
# create binary columns for sex and alone
df['sex'] = df['sex'].apply(lambda x: 0 if str(x) == 'male' else 1)
df['alone'] = df.apply(lambda row: 1 if row['Parents/children aboard'] == 0 and row['Siblings/spouses aboard'] == 0 else 0, axis=1)
# fill null values for age and fare
df['Age'].fillna(value=df['Age'].mean(), inplace=True)
df['Passenger fare'].fillna(value=df['Passenger fare'].mean(), inplace=True)
# drop unused columns
df.drop(['cabin', 'boat', 'body', 'ticket', 'name', 'Port of Embarkation', 'Home/Destination'], axis=1, inplace=True)

#change order of columns
new_order = ['sex', 'Survived', 'alone', 'Siblings/spouses aboard', 'Parents/children aboard', 'Passenger fare']
df = df[new_order]

df.head(5)
# Out:
#    sex  Survived  alone  Siblings/spouses aboard  Parents/children aboard  \
# 0    1         1      1                        0                        0
# 1    0         1      0                        1                        2
# 2    1         0      0                        1                        2
# 3    0         0      0                        1                        2
# 4    1         0      0                        1                        2
#
#    Passenger fare
# 0        211.3375
# 1        151.5500
# 2        151.5500
# 3        151.5500
# 4        151.5500

# %%
from pycaret.classification import *
s = setup(df, target = 'Survived', session_id=123)

best_survived = compare_models()

print(best_survived)

evaluate_model(best_survived)

#predict_model(best)
predict_model(best_survived, data=df.head(10))

save_model(best_survived, 'my_best_pipeline_survived')
# Out:
# <style type="text/css">
# #T_9d7e8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9d7e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d7e8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9d7e8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d7e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d7e8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9d7e8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d7e8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9d7e8_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d7e8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9d7e8_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d7e8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9d7e8_row3_col1" class="data row3 col1" >(1309, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d7e8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9d7e8_row4_col1" class="data row4 col1" >(1309, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d7e8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9d7e8_row5_col1" class="data row5 col1" >(916, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d7e8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9d7e8_row6_col1" class="data row6 col1" >(393, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d7e8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9d7e8_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d7e8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9d7e8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d7e8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9d7e8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9d7e8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9d7e8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9d7e8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9d7e8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9d7e8_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_9d7e8_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9d7e8_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_9d7e8_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9d7e8_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_9d7e8_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9d7e8_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_9d7e8_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9d7e8_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_9d7e8_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9d7e8_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_9d7e8_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9d7e8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9d7e8_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_9d7e8_row18_col1" class="data row18 col1" >0a05</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                19:23:49
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extra Trees Classifier
# <style type="text/css">
# #T_7c577 th {
#   text-align: left;
# }
# #T_7c577_row0_col0, #T_7c577_row0_col1, #T_7c577_row0_col2, #T_7c577_row0_col3, #T_7c577_row0_col4, #T_7c577_row0_col5, #T_7c577_row0_col6, #T_7c577_row0_col7, #T_7c577_row0_col8, #T_7c577_row1_col0, #T_7c577_row1_col1, #T_7c577_row1_col2, #T_7c577_row1_col3, #T_7c577_row1_col4, #T_7c577_row1_col5, #T_7c577_row1_col6, #T_7c577_row1_col7, #T_7c577_row1_col8, #T_7c577_row2_col0, #T_7c577_row2_col1, #T_7c577_row2_col2, #T_7c577_row2_col3, #T_7c577_row2_col4, #T_7c577_row2_col5, #T_7c577_row2_col6, #T_7c577_row2_col7, #T_7c577_row2_col8, #T_7c577_row3_col0, #T_7c577_row3_col1, #T_7c577_row3_col2, #T_7c577_row3_col3, #T_7c577_row3_col4, #T_7c577_row3_col5, #T_7c577_row3_col6, #T_7c577_row3_col7, #T_7c577_row3_col8, #T_7c577_row4_col0, #T_7c577_row4_col1, #T_7c577_row4_col2, #T_7c577_row4_col3, #T_7c577_row4_col4, #T_7c577_row4_col5, #T_7c577_row4_col6, #T_7c577_row4_col7, #T_7c577_row4_col8, #T_7c577_row5_col0, #T_7c577_row5_col1, #T_7c577_row5_col2, #T_7c577_row5_col3, #T_7c577_row5_col4, #T_7c577_row5_col5, #T_7c577_row5_col6, #T_7c577_row5_col7, #T_7c577_row5_col8, #T_7c577_row6_col0, #T_7c577_row6_col1, #T_7c577_row6_col2, #T_7c577_row6_col3, #T_7c577_row6_col4, #T_7c577_row6_col5, #T_7c577_row6_col6, #T_7c577_row6_col7, #T_7c577_row6_col8, #T_7c577_row7_col0, #T_7c577_row7_col1, #T_7c577_row7_col2, #T_7c577_row7_col3, #T_7c577_row7_col4, #T_7c577_row7_col5, #T_7c577_row7_col6, #T_7c577_row7_col7, #T_7c577_row7_col8, #T_7c577_row8_col0, #T_7c577_row8_col1, #T_7c577_row8_col2, #T_7c577_row8_col3, #T_7c577_row8_col4, #T_7c577_row8_col5, #T_7c577_row8_col6, #T_7c577_row8_col7, #T_7c577_row8_col8, #T_7c577_row9_col0, #T_7c577_row9_col1, #T_7c577_row9_col2, #T_7c577_row9_col3, #T_7c577_row9_col4, #T_7c577_row9_col5, #T_7c577_row9_col6, #T_7c577_row9_col7, #T_7c577_row9_col8, #T_7c577_row10_col0, #T_7c577_row10_col1, #T_7c577_row10_col2, #T_7c577_row10_col3, #T_7c577_row10_col4, #T_7c577_row10_col5, #T_7c577_row10_col6, #T_7c577_row10_col7, #T_7c577_row10_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_7c577">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c577_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c577_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7c577_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7c577_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7c577_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7c577_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7c577_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7c577_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_7c577_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c577_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_7c577_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_7c577_row0_col1" class="data row0 col1" >0.7871</td>
#       <td id="T_7c577_row0_col2" class="data row0 col2" >0.8093</td>
#       <td id="T_7c577_row0_col3" class="data row0 col3" >0.6857</td>
#       <td id="T_7c577_row0_col4" class="data row0 col4" >0.7443</td>
#       <td id="T_7c577_row0_col5" class="data row0 col5" >0.7110</td>
#       <td id="T_7c577_row0_col6" class="data row0 col6" >0.5432</td>
#       <td id="T_7c577_row0_col7" class="data row0 col7" >0.5470</td>
#       <td id="T_7c577_row0_col8" class="data row0 col8" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_7c577_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_7c577_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7c577_row1_col1" class="data row1 col1" >0.7860</td>
#       <td id="T_7c577_row1_col2" class="data row1 col2" >0.8446</td>
#       <td id="T_7c577_row1_col3" class="data row1 col3" >0.6543</td>
#       <td id="T_7c577_row1_col4" class="data row1 col4" >0.7567</td>
#       <td id="T_7c577_row1_col5" class="data row1 col5" >0.6997</td>
#       <td id="T_7c577_row1_col6" class="data row1 col6" >0.5352</td>
#       <td id="T_7c577_row1_col7" class="data row1 col7" >0.5403</td>
#       <td id="T_7c577_row1_col8" class="data row1 col8" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_7c577_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_7c577_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_7c577_row2_col1" class="data row2 col1" >0.7849</td>
#       <td id="T_7c577_row2_col2" class="data row2 col2" >0.8301</td>
#       <td id="T_7c577_row2_col3" class="data row2 col3" >0.6914</td>
#       <td id="T_7c577_row2_col4" class="data row2 col4" >0.7351</td>
#       <td id="T_7c577_row2_col5" class="data row2 col5" >0.7096</td>
#       <td id="T_7c577_row2_col6" class="data row2 col6" >0.5396</td>
#       <td id="T_7c577_row2_col7" class="data row2 col7" >0.5429</td>
#       <td id="T_7c577_row2_col8" class="data row2 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_7c577_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_7c577_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_7c577_row3_col1" class="data row3 col1" >0.7838</td>
#       <td id="T_7c577_row3_col2" class="data row3 col2" >0.8178</td>
#       <td id="T_7c577_row3_col3" class="data row3 col3" >0.6657</td>
#       <td id="T_7c577_row3_col4" class="data row3 col4" >0.7472</td>
#       <td id="T_7c577_row3_col5" class="data row3 col5" >0.7016</td>
#       <td id="T_7c577_row3_col6" class="data row3 col6" >0.5332</td>
#       <td id="T_7c577_row3_col7" class="data row3 col7" >0.5376</td>
#       <td id="T_7c577_row3_col8" class="data row3 col8" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_7c577_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_7c577_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_7c577_row4_col1" class="data row4 col1" >0.7838</td>
#       <td id="T_7c577_row4_col2" class="data row4 col2" >0.8266</td>
#       <td id="T_7c577_row4_col3" class="data row4 col3" >0.6800</td>
#       <td id="T_7c577_row4_col4" class="data row4 col4" >0.7371</td>
#       <td id="T_7c577_row4_col5" class="data row4 col5" >0.7062</td>
#       <td id="T_7c577_row4_col6" class="data row4 col6" >0.5357</td>
#       <td id="T_7c577_row4_col7" class="data row4 col7" >0.5380</td>
#       <td id="T_7c577_row4_col8" class="data row4 col8" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_7c577_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_7c577_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_7c577_row5_col1" class="data row5 col1" >0.7827</td>
#       <td id="T_7c577_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_7c577_row5_col3" class="data row5 col3" >0.6686</td>
#       <td id="T_7c577_row5_col4" class="data row5 col4" >0.7400</td>
#       <td id="T_7c577_row5_col5" class="data row5 col5" >0.7011</td>
#       <td id="T_7c577_row5_col6" class="data row5 col6" >0.5313</td>
#       <td id="T_7c577_row5_col7" class="data row5 col7" >0.5342</td>
#       <td id="T_7c577_row5_col8" class="data row5 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_7c577_level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_7c577_row6_col0" class="data row6 col0" >Linear Discriminant Analysis</td>
#       <td id="T_7c577_row6_col1" class="data row6 col1" >0.7827</td>
#       <td id="T_7c577_row6_col2" class="data row6 col2" >0.8189</td>
#       <td id="T_7c577_row6_col3" class="data row6 col3" >0.6686</td>
#       <td id="T_7c577_row6_col4" class="data row6 col4" >0.7400</td>
#       <td id="T_7c577_row6_col5" class="data row6 col5" >0.7011</td>
#       <td id="T_7c577_row6_col6" class="data row6 col6" >0.5313</td>
#       <td id="T_7c577_row6_col7" class="data row6 col7" >0.5342</td>
#       <td id="T_7c577_row6_col8" class="data row6
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
from pycaret.classification import *
s = setup(df, target = 'sex', session_id=123)

best_sex = compare_models()

print(best_sex)

evaluate_model(best_sex)

#predict_model(best)
predict_model(best_sex, data=df.head(10))

save_model(best_sex, 'my_best_pipeline_sex')
# Out:
# <style type="text/css">
# #T_3192b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3192b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3192b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3192b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3192b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3192b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3192b_row0_col1" class="data row0 col1" >2501</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3192b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3192b_row1_col1" class="data row1 col1" >sex</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3192b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3192b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3192b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3192b_row3_col1" class="data row3 col1" >(1309, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3192b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3192b_row4_col1" class="data row4 col1" >(1309, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3192b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3192b_row5_col1" class="data row5 col1" >(916, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3192b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3192b_row6_col1" class="data row6 col1" >(393, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3192b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3192b_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3192b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3192b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3192b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3192b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3192b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3192b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3192b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3192b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3192b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_3192b_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3192b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_3192b_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3192b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_3192b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3192b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_3192b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3192b_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_3192b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3192b_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_3192b_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3192b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3192b_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_3192b_row18_col1" class="data row18 col1" >fedb</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8ee52 th {
#   text-align: left;
# }
# #T_8ee52_row0_col0, #T_8ee52_row0_col2, #T_8ee52_row0_col3, #T_8ee52_row0_col5, #T_8ee52_row0_col6, #T_8ee52_row0_col7, #T_8ee52_row1_col0, #T_8ee52_row1_col3, #T_8ee52_row1_col4, #T_8ee52_row1_col5, #T_8ee52_row1_col6, #T_8ee52_row1_col7, #T_8ee52_row2_col0, #T_8ee52_row2_col1, #T_8ee52_row2_col2, #T_8ee52_row2_col4, #T_8ee52_row3_col0, #T_8ee52_row3_col1, #T_8ee52_row3_col2, #T_8ee52_row3_col4, #T_8ee52_row3_col5, #T_8ee52_row3_col6, #T_8ee52_row3_col7, #T_8ee52_row4_col0, #T_8ee52_row4_col1, #T_8ee52_row4_col2, #T_8ee52_row4_col3, #T_8ee52_row4_col4, #T_8ee52_row4_col5, #T_8ee52_row4_col6, #T_8ee52_row4_col7, #T_8ee52_row5_col0, #T_8ee52_row5_col1, #T_8ee52_row5_col2, #T_8ee52_row5_col3, #T_8ee52_row5_col4, #T_8ee52_row5_col5, #T_8ee52_row5_col6, #T_8ee52_row5_col7, #T_8ee52_row6_col0, #T_8ee52_row6_col1, #T_8ee52_row6_col2, #T_8ee52_row6_col3, #T_8ee52_row6_col4, #T_8ee52_row6_col5, #T_8ee52_row6_col6, #T_8ee52_row6_col7, #T_8ee52_row7_col0, #T_8ee52_row7_col1, #T_8ee52_row7_col2, #T_8ee52_row7_col3, #T_8ee52_row7_col4, #T_8ee52_row7_col5, #T_8ee52_row7_col6, #T_8ee52_row7_col7, #T_8ee52_row8_col0, #T_8ee52_row8_col1, #T_8ee52_row8_col2, #T_8ee52_row8_col3, #T_8ee52_row8_col4, #T_8ee52_row8_col5, #T_8ee52_row8_col6, #T_8ee52_row8_col7, #T_8ee52_row9_col0, #T_8ee52_row9_col1, #T_8ee52_row9_col2, #T_8ee52_row9_col3, #T_8ee52_row9_col4, #T_8ee52_row9_col5, #T_8ee52_row9_col6, #T_8ee52_row9_col7, #T_8ee52_row10_col0, #T_8ee52_row10_col1, #T_8ee52_row10_col2, #T_8ee52_row10_col3, #T_8ee52_row10_col4, #T_8ee52_row10_col5, #T_8ee52_row10_col6, #T_8ee52_row10_col7, #T_8ee52_row11_col0, #T_8ee52_row11_col1, #T_8ee52_row11_col2, #T_8ee52_row11_col3, #T_8ee52_row11_col4, #T_8ee52_row11_col5, #T_8ee52_row11_col6, #T_8ee52_row11_col7, #T_8ee52_row12_col0, #T_8ee52_row12_col1, #T_8ee52_row12_col2, #T_8ee52_row12_col3, #T_8ee52_row12_col4, #T_8ee52_row12_col5, #T_8ee52_row12_col6, #T_8ee52_row12_col7, #T_8ee52_row13_col0, #T_8ee52_row13_col1, #T_8ee52_row13_col2, #T_8ee52_row13_col3, #T_8ee52_row13_col4, #T_8ee52_row13_col5, #T_8ee52_row13_col6, #T_8ee52_row13_col7 {
#   text-align: left;
# }
# #T_8ee52_row0_col1, #T_8ee52_row0_col4, #T_8ee52_row1_col1, #T_8ee52_row1_col2, #T_8ee52_row2_col3, #T_8ee52_row2_col5, #T_8ee52_row2_col6, #T_8ee52_row2_col7, #T_8ee52_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8ee52_row0_col8, #T_8ee52_row1_col8, #T_8ee52_row3_col8, #T_8ee52_row4_col8, #T_8ee52_row5_col8, #T_8ee52_row6_col8, #T_8ee52_row7_col8, #T_8ee52_row8_col8, #T_8ee52_row9_col8, #T_8ee52_row10_col8, #T_8ee52_row11_col8, #T_8ee52_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8ee52_row2_col8, #T_8ee52_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8ee52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ee52_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8ee52_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8ee52_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8ee52_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8ee52_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8ee52_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8ee52_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8ee52_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8ee52_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ee52_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_8ee52_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_8ee52_row0_col1" class="data row0 col1" >0.7849</td>
#       <td id="T_8ee52_row0_col2" class="data row0 col2" >0.8293</td>
#       <td id="T_8ee52_row0_col3" class="data row0 col3" >0.6629</td>
#       <td id="T_8ee52_row0_col4" class="data row0 col4" >0.7181</td>
#       <td id="T_8ee52_row0_col5" class="data row0 col5" >0.6851</td>
#       <td id="T_8ee52_row0_col6" class="data row0 col6" >0.5230</td>
#       <td id="T_8ee52_row0_col7" class="data row0 col7" >0.5273</td>
#       <td id="T_8ee52_row0_col8" class="data row0 col8" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_8ee52_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_8ee52_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_8ee52_row1_col1" class="data row1 col1" >0.7849</td>
#       <td id="T_8ee52_row1_col2" class="data row1 col2" >0.8469</td>
#       <td id="T_8ee52_row1_col3" class="data row1 col3" >0.6814</td>
#       <td id="T_8ee52_row1_col4" class="data row1 col4" >0.7094</td>
#       <td id="T_8ee52_row1_col5" class="data row1 col5" >0.6914</td>
#       <td id="T_8ee52_row1_col6" class="data row1 col6" >0.5272</td>
#       <td id="T_8ee52_row1_col7" class="data row1 col7" >0.5306</td>
#       <td id="T_8ee52_row1_col8" class="data row1 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_8ee52_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_8ee52_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_8ee52_row2_col1" class="data row2 col1" >0.7848</td>
#       <td id="T_8ee52_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_8ee52_row2_col3" class="data row2 col3" >0.7302</td>
#       <td id="T_8ee52_row2_col4" class="data row2 col4" >0.6906</td>
#       <td id="T_8ee52_row2_col5" class="data row2 col5" >0.7077</td>
#       <td id="T_8ee52_row2_col6" class="data row2 col6" >0.5382</td>
#       <td id="T_8ee52_row2_col7" class="data row2 col7" >0.5407</td>
#       <td id="T_8ee52_row2_col8" class="data row2 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_8ee52_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_8ee52_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_8ee52_row3_col1" class="data row3 col1" >0.7837</td>
#       <td id="T_8ee52_row3_col2" class="data row3 col2" >0.8299</td>
#       <td id="T_8ee52_row3_col3" class="data row3 col3" >0.7302</td>
#       <td id="T_8ee52_row3_col4" class="data row3 col4" >0.6889</td>
#       <td id="T_8ee52_row3_col5" class="data row3 col5" >0.7067</td>
#       <td id="T_8ee52_row3_col6" class="data row3 col6" >0.5363</td>
#       <td id="T_8ee52_row3_col7" class="data row3 col7" >0.5389</td>
#       <td id="T_8ee52_row3_col8" class="data row3 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_8ee52_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_8ee52_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_8ee52_row4_col1" class="data row4 col1" >0.7826</td>
#       <td id="T_8ee52_row4_col2" class="data row4 col2" >0.8286</td>
#       <td id="T_8ee52_row4_col3" class="data row4 col3" >0.7272</td>
#       <td id="T_8ee52_row4_col4" class="data row4 col4" >0.6880</td>
#       <td id="T_8ee52_row4_col5" class="data row4 col5" >0.7049</td>
#       <td id="T_8ee52_row4_col6" class="data row4 col6" >0.5337</td>
#       <td id="T_8ee52_row4_col7" class="data row4 col7" >0.5362</td>
#       <td id="T_8ee52_row4_col8" class="data row4 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_8ee52_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_8ee52_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8ee52_row5_col1" class="data row5 col1" >0.7685</td>
#       <td id="T_8ee52_row5_col2" class="data row5 col2" >0.8315</td>
#       <td id="T_8ee52_row5_col3" class="data row5 col3" >0.6446</td>
#       <td id="T_8ee52_row5_col4" class="data row5 col4" >0.6890</td>
#       <td id="T_8ee52_row5_col5" class="data row5 col5" >0.6617</td>
#       <td id="T_8ee52_row5_col6" class="data row5 col6" >0.4872</td>
#       <td id="T_8ee52_row5_col7" class="data row5 col7" >0.4910</td>
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator='deprecated',
#                    estimator=None, learning_rate=1.0, n_estimators=50,
#                    random_state=2501)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_a7911">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7911_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7911_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a7911_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a7911_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a7911_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a7911_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a7911_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a7911_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7911_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7911_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_a7911_row0_col1" class="data row0 col1" >0.6000</td>
#       <td id="T_a7911_row0_col2" class="data row0 col2" >0.6800</td>
#       <td id="T_a7911_row0_col3" class="data row0 col3" >0.6000</td>
#       <td id="T_a7911_row0_col4" class="data row0 col4" >0.6000</td>
#       <td id="T_a7911_row0_col5" class="data row0 col5" >0.6000</td>
#       <td id="T_a7911_row0_col6" class="data row0 col6" >0.2000</td>
#       <td id="T_a7911_row0_col7" class="data row0 col7" >0.2000</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Survived', 'alone',
#                                               'Siblings/spouses aboard',
#                                               'Parents/children aboard',
#                                               'Passenger fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent',
#                                                                verbose='deprecated'))),
#                  ('clean_column_names',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   AdaBoostClassifier(algorithm='SAMME.R',
#                                      base_estimator='deprecated', estimator=None,
#                                      learning_rate=1.0, n_estimators=50,
#                                      random_state=2501))],
#           verbose=False),
#  'my_best_pipeline_sex.pkl')

# %%
from pycaret.clustering import *
s = setup(df, normalize=True)

kmeans = create_model('kmeans')

print(kmeans)

evaluate_model(kmeans)

plot_model(kmeans, plot = 'elbow')

plot_model(kmeans, plot = 'silhouette')

result = assign_model(kmeans)
result.head()

# predictions = predict_model(kmeans, data = df)
# predictions.head()

save_model(kmeans, 'kmeans_pipeline')
# Out:
# <style type="text/css">
# #T_c6500_row4_col1, #T_c6500_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c6500">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6500_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c6500_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6500_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6500_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c6500_row0_col1" class="data row0 col1" >5289</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6500_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_c6500_row1_col1" class="data row1 col1" >(1309, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6500_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_c6500_row2_col1" class="data row2 col1" >(1309, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6500_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_c6500_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c6500_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_c6500_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c6500_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_c6500_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c6500_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_c6500_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c6500_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_c6500_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c6500_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_c6500_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c6500_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_c6500_row9_col1" class="data row9 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c6500_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_c6500_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c6500_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_c6500_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c6500_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_c6500_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c6500_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_c6500_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c6500_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c6500_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_c6500_row14_col1" class="data row14 col1" >42c6</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ea26c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea26c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ea26c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ea26c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ea26c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ea26c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ea26c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea26c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea26c_row0_col0" class="data row0 col0" >0.4528</td>
#       <td id="T_ea26c_row0_col1" class="data row0 col1" >480.6745</td>
#       <td id="T_ea26c_row0_col2" class="data row0 col2" >1.3093</td>
#       <td id="T_ea26c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ea26c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ea26c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# KMeans(algorithm='lloyd', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init='warn', random_state=5289, tol=0.0001, verbose=0)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['sex', 'Survived', 'alone',
#                                               'Siblings/spouses aboard',
#                                               'Parents/children aboard',
#                                               'Passenger fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecate...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent',
#                                                                verbose='deprecated'))),
#                  ('normalize',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=StandardScaler(copy=True,
#                                                                 with_mean=True,
#                                                                 with_std=True))),
#                  ('trained_model',
#                   KMeans(algorithm='lloyd', copy_x=True, init='k-means++',
#                          max_iter=300, n_clusters=4, n_init='warn',
#                          random_state=5289, tol=0.0001, verbose=0))],
#           verbose=False),
#  'kmeans_pipeline.pkl')
